# %% [markdown]
# # Artificial Intelligence Nanodegree
#
# ## Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# > **Note**: Once you have completed all of the code implementations, you need to finalize your work by exporting the iPython Notebook as an HTML document. Before exporting the notebook to html, all of the code cells need to have been run so that reviewers can see the final implementation and output. You can then export the notebook by using the menu above and navigating to  \n",
#     "**File -> Download as -> HTML (.html)**. Include the finished document along with this notebook as your submission.
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this IPython notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Use a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 6](#step6): Write your Algorithm
# * [Step 7](#step7): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# ### Import Dog Dataset
#
# In the code cell below, we import a dataset of dog images.  We populate a few variables through the use of the `load_files` function from the scikit-learn library:
# - `train_files`, `valid_files`, `test_files` - numpy arrays containing file paths to images
# - `train_targets`, `valid_targets`, `test_targets` - numpy arrays containing onehot-encoded classification labels
# - `dog_names` - list of string-valued dog breed names for translating labels

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('dogImages/train')
valid_files, valid_targets = load_dataset('dogImages/valid')
test_files, test_targets = load_dataset('dogImages/test')

# load list of dog names
dog_names = [item[20:-1] for item in sorted(glob("dogImages/train/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# Using TensorFlow backend.
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### Import Human Dataset
#
# In the code cell below, we import a dataset of human images, where the file paths are stored in the numpy array `human_files`.

# %%
import random
random.seed(8675309)

# load filenames in shuffled human dataset
human_files = np.array(glob("lfw/*/*"))
random.shuffle(human_files)

# print statistics about the dataset
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13233 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# We use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.  OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.
#
# In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[123])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.
#
# __Answer:__  A human face is detected in 99% and 11% of human_files_short and dog_files_short respectively.

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
# Do NOT modify the code above this line.

## TODO: Test the performance of the face_detector algorithm 
num_human_in_humanPic=0
num_human_in_dogPic=0
for human_file in human_files_short:
    if face_detector(human_file):
        num_human_in_humanPic += 1
for dog_file in dog_files_short:
    if face_detector(dog_file):
        num_human_in_dogPic += 1

print(num_human_in_humanPic/100)
print(num_human_in_dogPic/100)
## on the images in human_files_short and dog_files_short.
# Out:
# 0.99
# 0.11

# %% [markdown]
# __Question 2:__ This algorithmic choice necessitates that we communicate to the user that we accept human images only when they provide a clear view of a face (otherwise, we risk having unneccessarily frustrated users!). In your opinion, is this a reasonable expectation to pose on the user? If not, can you think of a way to detect humans in images that does not necessitate an image with a clearly presented face?
#
# __Answer:__ I find it reasonable. Being a user of some face-recognizing APPs myself, I would personally understand that certain pictures can be treated well whereas others cannot and it is sometimes hilarious to play with them. So I think this kind of notice is tolerable.
#
# If we were to build a more robust model that can deal with faces in a variety of circumstances, like hidden in the shadow, partly presented or with a heavy makeup, etc., then I think some preprocessing on the image is necessary, like brightening the dark area. And another model needs to be trained to find humans not based on faces but on body shapes.
#
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on each of the datasets.

# %%
## (Optional) TODO: Report the performance of another  
## face detection algorithm on the LFW dataset
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a pre-trained [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) model to detect dogs in images.  Our first line of code downloads the ResNet-50 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).  Given an image, this pre-trained ResNet-50 model returns a prediction (derived from the available categories in ImageNet) for the object that is contained in the image.

# %%
from keras.applications.resnet50 import ResNet50

# define ResNet50 model
ResNet50_model = ResNet50(weights='imagenet')

# %% [markdown]
# ### Pre-process the Data
#
# When using TensorFlow as backend, Keras CNNs require a 4D array (which we'll also refer to as a 4D tensor) as input, with shape
#
# $$
# (\text{nb_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# where `nb_samples` corresponds to the total number of images (or samples), and `rows`, `columns`, and `channels` correspond to the number of rows, columns, and channels for each image, respectively.
#
# The `path_to_tensor` function below takes a string-valued file path to a color image as input and returns a 4D tensor suitable for supplying to a Keras CNN.  The function first loads the image and resizes it to a square image that is $224 \times 224$ pixels.  Next, the image is converted to an array, which is then resized to a 4D tensor.  In this case, since we are working with color images, each image has three channels.  Likewise, since we are processing a single image (or sample), the returned tensor will always have shape
#
# $$
# (1, 224, 224, 3).
# $$
#
# The `paths_to_tensor` function takes a numpy array of string-valued image paths as input and returns a 4D tensor with shape
#
# $$
# (\text{nb_samples}, 224, 224, 3).
# $$
#
# Here, `nb_samples` is the number of samples, or number of images, in the supplied array of image paths.  It is best to think of `nb_samples` as the number of 3D tensors (where each 3D tensor corresponds to a different image) in your dataset!

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# ### Making Predictions with ResNet-50
#
# Getting the 4D tensor ready for ResNet-50, and for any other pre-trained model in Keras, requires some additional processing.  First, the RGB image is converted to BGR by reordering the channels.  All pre-trained models have the additional normalization step that the mean pixel (expressed in RGB as $[103.939, 116.779, 123.68]$ and calculated from all pixels in all images in ImageNet) must be subtracted from every pixel in each image.  This is implemented in the imported function `preprocess_input`.  If you're curious, you can check the code for `preprocess_input` [here](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py).
#
# Now that we have a way to format our image for supplying to ResNet-50, we are now ready to use the model to extract the predictions.  This is accomplished with the `predict` method, which returns an array whose $i$-th entry is the model's predicted probability that the image belongs to the $i$-th ImageNet category.  This is implemented in the `ResNet50_predict_labels` function below.
#
# By taking the argmax of the predicted probability vector, we obtain an integer corresponding to the model's predicted object class, which we can identify with an object category through the use of this [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
from keras.applications.resnet50 import preprocess_input, decode_predictions

def ResNet50_predict_labels(img_path):
    # returns prediction vector for image located at img_path
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %% [markdown]
# ### Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained ResNet-50 model, we need only check if the `ResNet50_predict_labels` function above returns a value between 151 and 268 (inclusive).
#
# We use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# __Question 3:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?
#
# __Answer:__ 1% of images in `human_files_short` have a detected dog; 100% images in `dog_files_short` have a detected dog;

# %%
### TODO: Test the performance of the dog_detector function

num_dog_in_humanPic=0
for human_file in human_files_short:
    if dog_detector(human_file):
        num_dog_in_humanPic += 1

num_dog_in_dogPic=0
for dog_file in dog_files_short:
    if dog_detector(dog_file):
        num_dog_in_dogPic += 1

print(num_dog_in_dogPic/100)
print(num_dog_in_humanPic/100)

### on the images in human_files_short and dog_files_short.

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 1%.  In Step 5 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# Be careful with adding too many trainable layers!  More parameters means longer training, which means you are more likely to need a GPU to accelerate the training process.  Thankfully, Keras provides a handy estimate of the time that each epoch is likely to take; you can extrapolate this estimate to figure out how long it will take for your algorithm to train.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have great difficulty in distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### Pre-process the Data
#
# We rescale the images by dividing every pixel in every image by 255.

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|███████████████████████████| 6680/6680 [00:48<00:00, 136.93it/s]
# 100%|█████████████████████████████| 835/835 [00:05<00:00, 154.00it/s]
# 100%|█████████████████████████████| 836/836 [00:05<00:00, 159.12it/s]

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         model.summary()
#
# We have imported some Python modules to get you started, but feel free to import as many modules as you need.  If you end up getting stuck, here's a hint that specifies a model that trains relatively fast on CPU and attains >1% test accuracy in 5 epochs:
#
# ![Sample CNN](images/sample_cnn.png)
#
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  If you chose to use the hinted architecture above, describe why you think that CNN architecture should work well for the image classification task.
#
# __Answer:__
# * I tried the hinted architecture
# * I then added two dropout layers inside the hinted architecture, but I think dropout is non necessary since the network is shallow and not yet subject to overfitting;
#
# * TODO: try the mini-VGG architecture
#
# * TODO: try the mini-Inception architecture---wider layer consists of conv1, conv3, conv5 and pool;
#
# * TODO: try the mini-ResNet-50 architecture;

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential

BenchmarkModel = Sequential()

### TODO: Define your architecture.
BenchmarkModel = Sequential()
BenchmarkModel.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(224, 224, 3)))
BenchmarkModel.add(MaxPooling2D(pool_size=2))
BenchmarkModel.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
BenchmarkModel.add(MaxPooling2D(pool_size=2))
BenchmarkModel.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
BenchmarkModel.add(MaxPooling2D(pool_size=2))
BenchmarkModel.add(GlobalAveragePooling2D())
BenchmarkModel.add(Dense(133, activation='softmax'))

BenchmarkModel.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 224, 224, 16)      208
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 112, 112, 32)      2080
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 56, 56, 64)        8256
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 133)               8645
# =================================================================
# Total params: 19,189.0
# Trainable params: 19,189.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential

MiniVGGModel = Sequential()

### TODO: Define your architecture.
MiniVGGModel = Sequential()
MiniVGGModel.add(Conv2D(filters=16, kernel_size=2, padding='same', activation='relu', 
                        input_shape=(224, 224, 3)))
MiniVGGModel.add(MaxPooling2D(pool_size=2))
MiniVGGModel.add(Conv2D(filters=32, kernel_size=2, padding='same', activation='relu'))
MiniVGGModel.add(MaxPooling2D(pool_size=2))
MiniVGGModel.add(Conv2D(filters=64, kernel_size=2, padding='same', activation='relu'))
MiniVGGModel.add(MaxPooling2D(pool_size=2))
MiniVGGModel.add(Conv2D(filters=128, kernel_size=2, padding='same', activation='relu'))
MiniVGGModel.add(MaxPooling2D(pool_size=2))
MiniVGGModel.add(GlobalAveragePooling2D())
MiniVGGModel.add(Dense(133, activation='softmax'))

MiniVGGModel.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_4 (Conv2D)            (None, 224, 224, 16)      208
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 112, 112, 16)      0
# _________________________________________________________________
# conv2d_5 (Conv2D)            (None, 112, 112, 32)      2080
# _________________________________________________________________
# max_pooling2d_5 (MaxPooling2 (None, 56, 56, 32)        0
# _________________________________________________________________
# conv2d_6 (Conv2D)            (None, 56, 56, 64)        8256
# _________________________________________________________________
# max_pooling2d_6 (MaxPooling2 (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_7 (Conv2D)            (None, 28, 28, 128)       32896
# _________________________________________________________________
# max_pooling2d_7 (MaxPooling2 (None, 14, 14, 128)       0
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 128)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               17157
# =================================================================
# Total params: 60,597.0
# Trainable params: 60,597.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %%
from keras.layers import Input, concatenate, AveragePooling2D, Activation
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Model

input_img = Input(shape=(224, 224, 3))

conv1_7x7 = Conv2D(16, (7,7), padding='same', activation='relu')(input_img)
pool1_3x3 = MaxPooling2D(pool_size=3, strides=(2,2), padding='same')(conv1_7x7)

# following is the first inception without bottleneck 
incep1_Conv1x1 = Conv2D(32, (1, 1), padding='same', activation='relu')(pool1_3x3)
incep1_Conv3x3 = Conv2D(64, (3, 3), padding='same', activation='relu')(pool1_3x3)
incep1_Conv5x5 = Conv2D(16, (5, 5), padding='same', activation='relu')(pool1_3x3)
incep1_Pool = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(pool1_3x3)
incep1_Pool = Conv2D(16, (1, 1), padding='same', activation='relu')(pool1_3x3)
incep1_output = concatenate([incep1_Conv1x1, incep1_Conv3x3, incep1_Conv5x5, incep1_Pool], axis=-1)

pool2_3x3 = MaxPooling2D(pool_size=3, strides=(2,2), padding='same')(incep1_output)

# following is the second inception with bottleneck
incep2_Conv1x1 = Conv2D(32, (1, 1), padding='same', activation='relu')(pool2_3x3)
incep2_Conv3x3 = Conv2D(16, (1, 1), padding='same', activation='relu')(pool2_3x3)
incep2_Conv3x3 = Conv2D(64, (3, 3), padding='same', activation='relu')(incep2_Conv3x3)
incep2_Conv5x5 = Conv2D(8, (1, 1), padding='same', activation='relu')(pool2_3x3)
incep2_Conv5x5 = Conv2D(16, (5, 5), padding='same', activation='relu')(incep2_Conv5x5)
incep2_Pool = MaxPooling2D((3, 3), strides=(1, 1), padding='same')(pool2_3x3)
incep2_Pool = Conv2D(16, (1, 1), padding='same', activation='relu')(incep2_Pool)
incep2_output = concatenate([incep2_Conv1x1, incep2_Conv3x3, incep2_Conv5x5, incep2_Pool], axis=-1)

loss1_max_pool = MaxPooling2D((7, 7))(incep2_output)
loss1_ave_pool = GlobalAveragePooling2D()(loss1_max_pool)
loss1_classifier = Dense(133,activation='softmax')(loss1_ave_pool)    

MiniInceptionModel = Model(inputs=input_img, outputs=loss1_classifier)
                       
MiniInceptionModel.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_1 (InputLayer)             (None, 224, 224, 3)   0
# ____________________________________________________________________________________________________
# conv2d_8 (Conv2D)                (None, 224, 224, 16)  2368
# ____________________________________________________________________________________________________
# max_pooling2d_8 (MaxPooling2D)   (None, 112, 112, 16)  0
# ____________________________________________________________________________________________________
# conv2d_9 (Conv2D)                (None, 112, 112, 32)  544
# ____________________________________________________________________________________________________
# conv2d_10 (Conv2D)               (None, 112, 112, 64)  9280
# ____________________________________________________________________________________________________
# conv2d_11 (Conv2D)               (None, 112, 112, 16)  6416
# ____________________________________________________________________________________________________
# conv2d_12 (Conv2D)               (None, 112, 112, 16)  272
# ____________________________________________________________________________________________________
# concatenate_1 (Concatenate)      (None, 112, 112, 128) 0
# ____________________________________________________________________________________________________
# max_pooling2d_10 (MaxPooling2D)  (None, 56, 56, 128)   0
# ____________________________________________________________________________________________________
# conv2d_14 (Conv2D)               (None, 56, 56, 16)    2064
# ____________________________________________________________________________________________________
# conv2d_16 (Conv2D)               (None, 56, 56, 8)     1032
# ____________________________________________________________________________________________________
# max_pooling2d_11 (MaxPooling2D)  (None, 56, 56, 128)   0
# ____________________________________________________________________________________________________
# conv2d_13 (Conv2D)               (None, 56, 56, 32)    4128
# ____________________________________________________________________________________________________
# conv2d_15 (Conv2D)               (None, 56, 56, 64)    9280
# ____________________________________________________________________________________________________
# conv2d_17 (Conv2D)               (None, 56, 56, 16)    3216
# ____________________________________________________________________________________________________
# conv2d_18 (Conv2D)               (None, 56, 56, 16)    2064
# ____________________________________________________________________________________________________
# concatenate_2 (Concatenate)      (None, 56, 56, 128)   0
# ____________________________________________________________________________________________________
# max_pooling2d_12 (MaxPooling2D)  (None, 8, 8, 128)     0
# ____________________________________________________________________________________________________
# global_average_pooling2d_3 (Glob (None, 128)           0
# ____________________________________________________________________________________________________
# dense_3 (Dense)                  (None, 133)           17157
# ====================================================================================================
# Total params: 57,821.0
# Trainable params: 57,821.0
# Non-trainable params: 0.0
# ____________________________________________________________________________________________________

# %%
from keras.layers import Input, concatenate, AveragePooling2D, GlobalAveragePooling2D, Activation
from keras.layers import Conv2D, MaxPooling2D, Dropout, Flatten, Dense, add
from keras.models import Model

input_img = Input(shape=(224, 224, 3))

conv7x7 = Conv2D(16, (7, 7), strides = (2, 2), padding = 'same', activation = 'relu')(input_img)
pool3x3 = MaxPooling2D((3, 3), strides = (2, 2), padding = 'same')(conv7x7)

# the first residual module
res1_bottleneck_i = Conv2D(16, (1, 1), padding = 'same', activation = 'relu')(pool3x3)
res1_conv3x3 = Conv2D(16, (3, 3), padding = 'same', activation = 'relu')(res1_bottleneck_i)
res1_bottleneck_o = Conv2D(32, (1, 1), padding = 'same', activation = 'relu')(res1_conv3x3)

shortcut1 = Conv2D(32, (1, 1), padding = 'same', activation = 'relu')(pool3x3)
output1 = add([shortcut1, res1_bottleneck_o])

# the second residual module
res2_bottleneck_i = Conv2D(32, (1, 1), strides = (2, 2), padding = 'same', activation = 'relu')(output1)
res2_conv3x3 = Conv2D(32, (3, 3), padding = 'same', activation = 'relu')(res2_bottleneck_i)
res2_bottleneck_o = Conv2D(128, (1, 1), padding = 'same', activation = 'relu')(res2_conv3x3)

shortcut2 = Conv2D(128, (1, 1), strides = (2, 2), padding = 'same', activation = 'relu')(output1)
output2 = add([shortcut2, res2_bottleneck_o])

loss_ave_pool = GlobalAveragePooling2D()(output2)
loss_classifier = Dense(133, activation = 'softmax')(loss_ave_pool)
MiniResNetModel = Model(inputs=input_img, outputs=loss_classifier)

MiniResNetModel.summary()
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_2 (InputLayer)             (None, 224, 224, 3)   0
# ____________________________________________________________________________________________________
# conv2d_19 (Conv2D)               (None, 112, 112, 16)  2368
# ____________________________________________________________________________________________________
# max_pooling2d_13 (MaxPooling2D)  (None, 56, 56, 16)    0
# ____________________________________________________________________________________________________
# conv2d_20 (Conv2D)               (None, 56, 56, 16)    272
# ____________________________________________________________________________________________________
# conv2d_21 (Conv2D)               (None, 56, 56, 16)    2320
# ____________________________________________________________________________________________________
# conv2d_23 (Conv2D)               (None, 56, 56, 32)    544
# ____________________________________________________________________________________________________
# conv2d_22 (Conv2D)               (None, 56, 56, 32)    544
# ____________________________________________________________________________________________________
# add_1 (Add)                      (None, 56, 56, 32)    0
# ____________________________________________________________________________________________________
# conv2d_24 (Conv2D)               (None, 28, 28, 32)    1056
# ____________________________________________________________________________________________________
# conv2d_25 (Conv2D)               (None, 28, 28, 32)    9248
# ____________________________________________________________________________________________________
# conv2d_27 (Conv2D)               (None, 28, 28, 128)   4224
# ____________________________________________________________________________________________________
# conv2d_26 (Conv2D)               (None, 28, 28, 128)   4224
# ____________________________________________________________________________________________________
# add_2 (Add)                      (None, 28, 28, 128)   0
# ____________________________________________________________________________________________________
# global_average_pooling2d_4 (Glob (None, 128)           0
# ____________________________________________________________________________________________________
# dense_4 (Dense)                  (None, 133)           17157
# ====================================================================================================
# Total params: 41,957.0
# Trainable params: 41,957.0
# Non-trainable params: 0.0
# ____________________________________________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
BenchmarkModel.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
MiniVGGModel.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
MiniInceptionModel.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
MiniResNetModel.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 100

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.BenchmarkModel.hdf5', 
                               verbose=1, save_best_only=True)

BenchmarkModelHistory100 = BenchmarkModel.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=2)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/100
# Epoch 00000: val_loss improved from inf to 4.51240, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 4.4050 - acc: 0.0608 - val_loss: 4.5124 - val_acc: 0.0467
# Epoch 2/100
# Epoch 00001: val_loss improved from 4.51240 to 4.48290, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 25s - loss: 4.3784 - acc: 0.0632 - val_loss: 4.4829 - val_acc: 0.0491
# Epoch 3/100
# Epoch 00002: val_loss did not improve
# 25s - loss: 4.3580 - acc: 0.0636 - val_loss: 4.5000 - val_acc: 0.0395
# Epoch 4/100
# Epoch 00003: val_loss did not improve
# 24s - loss: 4.3343 - acc: 0.0671 - val_loss: 4.4887 - val_acc: 0.0491
# Epoch 5/100
# Epoch 00004: val_loss improved from 4.48290 to 4.45210, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 4.3113 - acc: 0.0693 - val_loss: 4.4521 - val_acc: 0.0491
# Epoch 6/100
# Epoch 00005: val_loss did not improve
# 24s - loss: 4.2952 - acc: 0.0729 - val_loss: 4.4862 - val_acc: 0.0551
# Epoch 7/100
# Epoch 00006: val_loss did not improve
# 24s - loss: 4.2719 - acc: 0.0753 - val_loss: 4.4532 - val_acc: 0.0503
# Epoch 8/100
# Epoch 00007: val_loss improved from 4.45210 to 4.40276, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 4.2541 - acc: 0.0759 - val_loss: 4.4028 - val_acc: 0.0539
# Epoch 9/100
# Epoch 00008: val_loss did not improve
# 24s - loss: 4.2329 - acc: 0.0801 - val_loss: 4.4712 - val_acc: 0.0587
# Epoch 10/100
# Epoch 00009: val_loss did not improve
# 24s - loss: 4.2160 - acc: 0.0784 - val_loss: 4.4634 - val_acc: 0.0599
# Epoch 11/100
# Epoch 00010: val_loss improved from 4.40276 to 4.35510, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 4.2011 - acc: 0.0849 - val_loss: 4.3551 - val_acc: 0.0551
# Epoch 12/100
# Epoch 00011: val_loss improved from 4.35510 to 4.34909, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 4.1790 - acc: 0.0813 - val_loss: 4.3491 - val_acc: 0.0695
# Epoch 13/100
# Epoch 00012: val_loss did not improve
# 24s - loss: 4.1672 - acc: 0.0817 - val_loss: 4.3555 - val_acc: 0.0671
# Epoch 14/100
# Epoch 00013: val_loss improved from 4.34909 to 4.30551, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 4.1505 - acc: 0.0840 - val_loss: 4.3055 - val_acc: 0.0623
# Epoch 15/100
# Epoch 00014: val_loss did not improve
# 24s - loss: 4.1351 - acc: 0.0889 - val_loss: 4.3610 - val_acc: 0.0659
# Epoch 16/100
# Epoch 00015: val_loss did not improve
# 24s - loss: 4.1234 - acc: 0.0862 - val_loss: 4.3373 - val_acc: 0.0599
# Epoch 17/100
# Epoch 00016: val_loss did not improve
# 24s - loss: 4.1092 - acc: 0.0889 - val_loss: 4.3222 - val_acc: 0.0683
# Epoch 18/100
# Epoch 00017: val_loss improved from 4.30551 to 4.29227, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 4.0929 - acc: 0.0913 - val_loss: 4.2923 - val_acc: 0.0731
# Epoch 19/100
# Epoch 00018: val_loss did not improve
# 24s - loss: 4.0832 - acc: 0.0924 - val_loss: 4.3043 - val_acc: 0.0778
# Epoch 20/100
# Epoch 00019: val_loss did not improve
# 24s - loss: 4.0715 - acc: 0.0978 - val_loss: 4.3139 - val_acc: 0.0743
# Epoch 21/100
# Epoch 00020: val_loss did not improve
# 24s - loss: 4.0601 - acc: 0.0943 - val_loss: 4.3219 - val_acc: 0.0695
# Epoch 22/100
# Epoch 00021: val_loss did not improve
# 24s - loss: 4.0426 - acc: 0.0970 - val_loss: 4.3435 - val_acc: 0.0766
# Epoch 23/100
# Epoch 00022: val_loss improved from 4.29227 to 4.28566, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 4.0388 - acc: 0.0921 - val_loss: 4.2857 - val_acc: 0.0743
# Epoch 24/100
# Epoch 00023: val_loss did not improve
# 24s - loss: 4.0301 - acc: 0.1016 - val_loss: 4.2877 - val_acc: 0.0731
# Epoch 25/100
# Epoch 00024: val_loss improved from 4.28566 to 4.24140, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 4.0131 - acc: 0.1046 - val_loss: 4.2414 - val_acc: 0.0826
# Epoch 26/100
# Epoch 00025: val_loss did not improve
# 25s - loss: 4.0042 - acc: 0.1055 - val_loss: 4.2998 - val_acc: 0.0719
# Epoch 27/100
# Epoch 00026: val_loss did not improve
# 24s - loss: 3.9971 - acc: 0.1058 - val_loss: 4.3166 - val_acc: 0.0766
# Epoch 28/100
# Epoch 00027: val_loss improved from 4.24140 to 4.23923, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 3.9812 - acc: 0.1064 - val_loss: 4.2392 - val_acc: 0.0814
# Epoch 29/100
# Epoch 00028: val_loss improved from 4.23923 to 4.18385, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 3.9666 - acc: 0.1070 - val_loss: 4.1838 - val_acc: 0.0814
# Epoch 30/100
# Epoch 00029: val_loss did not improve
# 24s - loss: 3.9648 - acc: 0.1081 - val_loss: 4.3277 - val_acc: 0.0778
# Epoch 31/100
# Epoch 00030: val_loss did not improve
# 24s - loss: 3.9503 - acc: 0.1126 - val_loss: 4.2647 - val_acc: 0.0850
# Epoch 32/100
# Epoch 00031: val_loss improved from 4.18385 to 4.17500, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 3.9435 - acc: 0.1157 - val_loss: 4.1750 - val_acc: 0.0862
# Epoch 33/100
# Epoch 00032: val_loss improved from 4.17500 to 4.17355, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 3.9298 - acc: 0.1165 - val_loss: 4.1735 - val_acc: 0.0838
# Epoch 34/100
# Epoch 00033: val_loss improved from 4.17355 to 4.14794, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 3.9214 - acc: 0.1118 - val_loss: 4.1479 - val_acc: 0.0862
# Epoch 35/100
# Epoch 00034: val_loss did not improve
# 24s - loss: 3.9117 - acc: 0.1210 - val_loss: 4.3435 - val_acc: 0.0802
# Epoch 36/100
# Epoch 00035: val_loss did not improve
# 24s - loss: 3.9016 - acc: 0.1153 - val_loss: 4.1814 - val_acc: 0.0886
# Epoch 37/100
# Epoch 00036: val_loss did not improve
# 24s - loss: 3.8886 - acc: 0.1244 - val_loss: 4.1500 - val_acc: 0.0934
# Epoch 38/100
# Epoch 00037: val_loss improved from 4.14794 to 4.12661, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 25s - loss: 3.8833 - acc: 0.1202 - val_loss: 4.1266 - val_acc: 0.0934
# Epoch 39/100
# Epoch 00038: val_loss did not improve
# 24s - loss: 3.8761 - acc: 0.1277 - val_loss: 4.1301 - val_acc: 0.0910
# Epoch 40/100
# Epoch 00039: val_loss did not improve
# 24s - loss: 3.8632 - acc: 0.1247 - val_loss: 4.2168 - val_acc: 0.0910
# Epoch 41/100
# Epoch 00040: val_loss did not improve
# 24s - loss: 3.8536 - acc: 0.1259 - val_loss: 4.1450 - val_acc: 0.0886
# Epoch 42/100
# Epoch 00041: val_loss did not improve
# 24s - loss: 3.8450 - acc: 0.1247 - val_loss: 4.2973 - val_acc: 0.1018
# Epoch 43/100
# Epoch 00042: val_loss improved from 4.12661 to 4.11563, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 3.8378 - acc: 0.1257 - val_loss: 4.1156 - val_acc: 0.1066
# Epoch 44/100
# Epoch 00043: val_loss did not improve
# 24s - loss: 3.8285 - acc: 0.1263 - val_loss: 4.1157 - val_acc: 0.0994
# Epoch 45/100
# Epoch 00044: val_loss improved from 4.11563 to 4.10624, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 3.8232 - acc: 0.1305 - val_loss: 4.1062 - val_acc: 0.1018
# Epoch 46/100
# Epoch 00045: val_loss improved from 4.10624 to 4.10226, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 3.8063 - acc: 0.1337 - val_loss: 4.1023 - val_acc: 0.0922
# Epoch 47/100
# Epoch 00046: val_loss improved from 4.10226 to 4.08797, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 3.8006 - acc: 0.1331 - val_loss: 4.0880 - val_acc: 0.1042
# Epoch 48/100
# Epoch 00047: val_loss did not improve
# 24s - loss: 3.7925 - acc: 0.1320 - val_loss: 4.1039 - val_acc: 0.0970
# Epoch 49/100
# Epoch 00048: val_loss did not improve
# 24s - loss: 3.7835 - acc: 0.1442 - val_loss: 4.1720 - val_acc: 0.1030
# Epoch 50/100
# Epoch 00049: val_loss improved from 4.08797 to 4.08573, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 3.7709 - acc: 0.1412 - val_loss: 4.0857 - val_acc: 0.0970
# Epoch 51/100
# Epoch 00050: val_loss did not improve
# 24s - loss: 3.7668 - acc: 0.1446 - val_loss: 4.0986 - val_acc: 0.0970
# Epoch 52/100
# Epoch 00051: val_loss did not improve
# 25s - loss: 3.7550 - acc: 0.1485 - val_loss: 4.1618 - val_acc: 0.0946
# Epoch 53/100
# Epoch 00052: val_loss improved from 4.08573 to 4.07096, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 3.7409 - acc: 0.1464 - val_loss: 4.0710 - val_acc: 0.1078
# Epoch 54/100
# Epoch 00053: val_loss improved from 4.07096 to 4.05973, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 3.7415 - acc: 0.1457 - val_loss: 4.0597 - val_acc: 0.1054
# Epoch 55/100
# Epoch 00054: val_loss improved from 4.05973 to 4.04590, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 3.7293 - acc: 0.1493 - val_loss: 4.0459 - val_acc: 0.1162
# Epoch 56/100
# Epoch 00055: val_loss did not improve
# 24s - loss: 3.7160 - acc: 0.1494 - val_loss: 4.1170 - val_acc: 0.1066
# Epoch 57/100
# Epoch 00056: val_loss did not improve
# 24s - loss: 3.7105 - acc: 0.1545 - val_loss: 4.0862 - val_acc: 0.1066
# Epoch 58/100
# Epoch 00057: val_loss did not improve
# 24s - loss: 3.7138 - acc: 0.1507 - val_loss: 4.0772 - val_acc: 0.1162
# Epoch 59/100
# Epoch 00058: val_loss did not improve
# 24s - loss: 3.6995 - acc: 0.1499 - val_loss: 4.1444 - val_acc: 0.0994
# Epoch 60/100
# Epoch 00059: val_loss did not improve
# 25s - loss: 3.6940 - acc: 0.1527 - val_loss: 4.0616 - val_acc: 0.1042
# Epoch 61/100
# Epoch 00060: val_loss did not improve
# 24s - loss: 3.6787 - acc: 0.1611 - val_loss: 4.1753 - val_acc: 0.1102
# Epoch 62/100
# Epoch 00061: val_loss improved from 4.04590 to 4.02781, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 25s - loss: 3.6738 - acc: 0.1590 - val_loss: 4.0278 - val_acc: 0.1162
# Epoch 63/100
# Epoch 00062: val_loss improved from 4.02781 to 4.00826, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 3.6763 - acc: 0.1618 - val_loss: 4.0083 - val_acc: 0.1305
# Epoch 64/100
# Epoch 00063: val_loss did not improve
# 24s - loss: 3.6640 - acc: 0.1618 - val_loss: 4.0240 - val_acc: 0.1269
# Epoch 65/100
# Epoch 00064: val_loss improved from 4.00826 to 3.99243, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 3.6570 - acc: 0.1606 - val_loss: 3.9924 - val_acc: 0.1090
# Epoch 66/100
# Epoch 00065: val_loss did not improve
# 24s - loss: 3.6485 - acc: 0.1584 - val_loss: 4.1094 - val_acc: 0.1198
# Epoch 67/100
# Epoch 00066: val_loss did not improve
# 24s - loss: 3.6457 - acc: 0.1677 - val_loss: 4.0493 - val_acc: 0.1174
# Epoch 68/100
# Epoch 00067: val_loss did not improve
# 24s - loss: 3.6346 - acc: 0.1645 - val_loss: 4.0064 - val_acc: 0.1222
# Epoch 69/100
# Epoch 00068: val_loss did not improve
# 25s - loss: 3.6264 - acc: 0.1665 - val_loss: 4.0189 - val_acc: 0.1138
# Epoch 70/100
# Epoch 00069: val_loss did not improve
# 25s - loss: 3.6210 - acc: 0.1729 - val_loss: 4.0390 - val_acc: 0.1257
# Epoch 71/100
# Epoch 00070: val_loss improved from 3.99243 to 3.97582, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 3.6102 - acc: 0.1723 - val_loss: 3.9758 - val_acc: 0.1210
# Epoch 72/100
# Epoch 00071: val_loss did not improve
# 24s - loss: 3.6121 - acc: 0.1690 - val_loss: 4.0212 - val_acc: 0.1198
# Epoch 73/100
# Epoch 00072: val_loss did not improve
# 24s - loss: 3.5977 - acc: 0.1708 - val_loss: 3.9944 - val_acc: 0.1222
# Epoch 74/100
# Epoch 00073: val_loss did not improve
# 24s - loss: 3.5963 - acc: 0.1737 - val_loss: 4.0611 - val_acc: 0.1317
# Epoch 75/100
# Epoch 00074: val_loss did not improve
# 25s - loss: 3.5852 - acc: 0.1738 - val_loss: 4.0342 - val_acc: 0.1281
# Epoch 76/100
# Epoch 00075: val_loss did not improve
# 24s - loss: 3.5806 - acc: 0.1741 - val_loss: 3.9820 - val_acc: 0.1150
# Epoch 77/100
# Epoch 00076: val_loss did not improve
# 24s - loss: 3.5755 - acc: 0.1754 - val_loss: 4.0094 - val_acc: 0.1365
# Epoch 78/100
# Epoch 00077: val_loss improved from 3.97582 to 3.96368, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 3.5685 - acc: 0.1753 - val_loss: 3.9637 - val_acc: 0.1210
# Epoch 79/100
# Epoch 00078: val_loss did not improve
# 24s - loss: 3.5682 - acc: 0.1796 - val_loss: 4.0071 - val_acc: 0.1114
# Epoch 80/100
# Epoch 00079: val_loss did not improve
# 24s - loss: 3.5547 - acc: 0.1766 - val_loss: 4.0591 - val_acc: 0.1222
# Epoch 81/100
# Epoch 00080: val_loss did not improve
# 25s - loss: 3.5510 - acc: 0.1822 - val_loss: 4.0940 - val_acc: 0.1006
# Epoch 82/100
# Epoch 00081: val_loss did not improve
# 25s - loss: 3.5459 - acc: 0.1781 - val_loss: 3.9710 - val_acc: 0.1293
# Epoch 83/100
# Epoch 00082: val_loss did not improve
# 24s - loss: 3.5397 - acc: 0.1814 - val_loss: 4.0328 - val_acc: 0.1281
# Epoch 84/100
# Epoch 00083: val_loss did not improve
# 24s - loss: 3.5350 - acc: 0.1838 - val_loss: 4.0440 - val_acc: 0.1305
# Epoch 85/100
# Epoch 00084: val_loss did not improve
# 24s - loss: 3.5302 - acc: 0.1849 - val_loss: 3.9919 - val_acc: 0.1198
# Epoch 86/100
# Epoch 00085: val_loss did not improve
# 24s - loss: 3.5209 - acc: 0.1871 - val_loss: 3.9712 - val_acc: 0.1102
# Epoch 87/100
# Epoch 00086: val_loss improved from 3.96368 to 3.92753, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 3.5152 - acc: 0.1868 - val_loss: 3.9275 - val_acc: 0.1293
# Epoch 88/100
# Epoch 00087: val_loss did not improve
# 24s - loss: 3.5101 - acc: 0.1844 - val_loss: 4.0306 - val_acc: 0.1293
# Epoch 89/100
# Epoch 00088: val_loss did not improve
# 24s - loss: 3.5031 - acc: 0.1910 - val_loss: 3.9604 - val_acc: 0.1353
# Epoch 90/100
# Epoch 00089: val_loss improved from 3.92753 to 3.92726, saving model to saved_models/weights.best.BenchmarkModel.hdf5
# 24s - loss: 3.4989 - acc: 0.1849 - val_loss: 3.9273 - val_acc: 0.1425
# Epoch 91/100
# Epoch 00090: val_loss did not improve
# 24s - loss: 3.4915 - acc: 0.1894 - val_loss: 4.0370 - val_acc: 0.1281
# Epoch 92/100
# Epoch 00091: val_loss did not improve
# 24s - loss: 3.4916 - acc: 0.1939 - val_loss: 3.9711 - val_acc: 0.1257
# Epoch 93/100
# Epoch 00092: val_loss did not improve
# 24s - loss: 3.4883 - acc: 0.1901 - val_loss: 3.9555 - val_acc: 0.1305
# Epoch 94/100
# Epoch 00093: val_loss did not improve
# 24s - loss: 3.4838 - acc: 0.1943 - val_loss: 3.9985 - val_acc: 0.1234
# Epoch 95/100
# Epoch 00094: val_loss did not improve
# 24s - loss: 3.4718 - acc: 0.1906 - val_loss: 3.9797 - val_acc: 0.1329
# Epoch 96/100
# Epoch 00095: val_loss did not improve
# 25s - loss: 3.4749 - acc: 0.1957 - val_loss: 4.0554 - val_acc: 0.1353
# Epoch 97/100
# Epoch 00096: val_loss did not improve
# 24s - loss: 3.4689 - acc: 0.1958 - val_loss: 3.9540 - val_acc: 0.1449
# Epoch 98/100
# Epoch 00097: val_loss did not improve
# 24s - loss: 3.4630 - acc: 0.1970 - val_loss: 4.0267 - val_acc: 0.1126
# Epoch 99/100
# Epoch 00098: val_loss did not improve
# 24s - loss: 3.4631 - acc: 0.1999 - val_loss: 3.9713 - val_acc: 0.1269
# Epoch 100/100
# Epoch 00099: val_loss did not improve
# 24s - loss: 3.4605 - acc: 0.1960 - val_loss: 4.0315 - val_acc: 0.1281

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 100

### Do NOT modify the code below this line.a

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.MiniVGGModel.hdf5', 
                               verbose=1, save_best_only=True)

MiniVGGHistory100 = MiniVGGModel.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=2)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/100
# Epoch 00000: val_loss improved from inf to 3.86013, saving model to saved_models/weights.best.MiniVGGModel.hdf5
# 26s - loss: 3.4572 - acc: 0.1772 - val_loss: 3.8601 - val_acc: 0.1281
# Epoch 2/100
# Epoch 00001: val_loss did not improve
# 26s - loss: 3.4357 - acc: 0.1873 - val_loss: 3.8718 - val_acc: 0.1162
# Epoch 3/100
# Epoch 00002: val_loss did not improve
# 26s - loss: 3.4022 - acc: 0.1930 - val_loss: 3.9202 - val_acc: 0.1234
# Epoch 4/100
# Epoch 00003: val_loss did not improve
# 26s - loss: 3.3915 - acc: 0.1933 - val_loss: 3.8656 - val_acc: 0.1341
# Epoch 5/100
# Epoch 00004: val_loss did not improve
# 26s - loss: 3.3639 - acc: 0.1936 - val_loss: 3.9129 - val_acc: 0.1210
# Epoch 6/100
# Epoch 00005: val_loss improved from 3.86013 to 3.85747, saving model to saved_models/weights.best.MiniVGGModel.hdf5
# 26s - loss: 3.3377 - acc: 0.2000 - val_loss: 3.8575 - val_acc: 0.1246
# Epoch 7/100
# Epoch 00006: val_loss did not improve
# 26s - loss: 3.3154 - acc: 0.2051 - val_loss: 3.9084 - val_acc: 0.1317
# Epoch 8/100
# Epoch 00007: val_loss improved from 3.85747 to 3.84509, saving model to saved_models/weights.best.MiniVGGModel.hdf5
# 26s - loss: 3.2914 - acc: 0.2100 - val_loss: 3.8451 - val_acc: 0.1365
# Epoch 9/100
# Epoch 00008: val_loss improved from 3.84509 to 3.76906, saving model to saved_models/weights.best.MiniVGGModel.hdf5
# 26s - loss: 3.2871 - acc: 0.2102 - val_loss: 3.7691 - val_acc: 0.1497
# Epoch 10/100
# Epoch 00009: val_loss did not improve
# 26s - loss: 3.2619 - acc: 0.2141 - val_loss: 3.8954 - val_acc: 0.1162
# Epoch 11/100
# Epoch 00010: val_loss did not improve
# 26s - loss: 3.2335 - acc: 0.2214 - val_loss: 3.8351 - val_acc: 0.1509
# Epoch 12/100
# Epoch 00011: val_loss did not improve
# 26s - loss: 3.2262 - acc: 0.2190 - val_loss: 3.8334 - val_acc: 0.1365
# Epoch 13/100
# Epoch 00012: val_loss did not improve
# 26s - loss: 3.1971 - acc: 0.2281 - val_loss: 3.8606 - val_acc: 0.1401
# Epoch 14/100
# Epoch 00013: val_loss improved from 3.76906 to 3.74970, saving model to saved_models/weights.best.MiniVGGModel.hdf5
# 26s - loss: 3.1756 - acc: 0.2269 - val_loss: 3.7497 - val_acc: 0.1509
# Epoch 15/100
# Epoch 00014: val_loss did not improve
# 26s - loss: 3.1547 - acc: 0.2349 - val_loss: 3.8020 - val_acc: 0.1413
# Epoch 16/100
# Epoch 00015: val_loss did not improve
# 26s - loss: 3.1362 - acc: 0.2376 - val_loss: 3.7827 - val_acc: 0.1521
# Epoch 17/100
# Epoch 00016: val_loss did not improve
# 26s - loss: 3.1096 - acc: 0.2434 - val_loss: 3.8045 - val_acc: 0.1605
# Epoch 18/100
# Epoch 00017: val_loss improved from 3.74970 to 3.71314, saving model to saved_models/weights.best.MiniVGGModel.hdf5
# 26s - loss: 3.1057 - acc: 0.2484 - val_loss: 3.7131 - val_acc: 0.1641
# Epoch 19/100
# Epoch 00018: val_loss did not improve
# 26s - loss: 3.0786 - acc: 0.2510 - val_loss: 4.0713 - val_acc: 0.1210
# Epoch 20/100
# Epoch 00019: val_loss did not improve
# 26s - loss: 3.0555 - acc: 0.2578 - val_loss: 3.7197 - val_acc: 0.1533
# Epoch 21/100
# Epoch 00020: val_loss did not improve
# 26s - loss: 3.0516 - acc: 0.2567 - val_loss: 3.7783 - val_acc: 0.1365
# Epoch 22/100
# Epoch 00021: val_loss did not improve
# 26s - loss: 3.0207 - acc: 0.2591 - val_loss: 3.8692 - val_acc: 0.1341
# Epoch 23/100
# Epoch 00022: val_loss did not improve
# 26s - loss: 3.0017 - acc: 0.2695 - val_loss: 3.7866 - val_acc: 0.1593
# Epoch 24/100
# Epoch 00023: val_loss did not improve
# 26s - loss: 2.9975 - acc: 0.2641 - val_loss: 3.7280 - val_acc: 0.1473
# Epoch 25/100
# Epoch 00024: val_loss improved from 3.71314 to 3.67477, saving model to saved_models/weights.best.MiniVGGModel.hdf5
# 26s - loss: 2.9800 - acc: 0.2757 - val_loss: 3.6748 - val_acc: 0.1784
# Epoch 26/100
# Epoch 00025: val_loss did not improve
# 26s - loss: 2.9477 - acc: 0.2731 - val_loss: 3.8666 - val_acc: 0.1665
# Epoch 27/100
# Epoch 00026: val_loss did not improve
# 26s - loss: 2.9327 - acc: 0.2775 - val_loss: 3.6861 - val_acc: 0.1521
# Epoch 28/100
# Epoch 00027: val_loss did not improve
# 26s - loss: 2.9152 - acc: 0.2864 - val_loss: 3.7265 - val_acc: 0.1689
# Epoch 29/100
# Epoch 00028: val_loss did not improve
# 26s - loss: 2.9072 - acc: 0.2835 - val_loss: 3.7773 - val_acc: 0.1641
# Epoch 30/100
# Epoch 00029: val_loss did not improve
# 26s - loss: 2.8864 - acc: 0.2877 - val_loss: 3.9593 - val_acc: 0.1701
# Epoch 31/100
# Epoch 00030: val_loss did not improve
# 26s - loss: 2.8554 - acc: 0.2979 - val_loss: 3.9368 - val_acc: 0.1293
# Epoch 32/100
# Epoch 00031: val_loss improved from 3.67477 to 3.64828, saving model to saved_models/weights.best.MiniVGGModel.hdf5
# 26s - loss: 2.8548 - acc: 0.2969 - val_loss: 3.6483 - val_acc: 0.1725
# Epoch 33/100
# Epoch 00032: val_loss did not improve
# 26s - loss: 2.8351 - acc: 0.2975 - val_loss: 3.6599 - val_acc: 0.1641
# Epoch 34/100
# Epoch 00033: val_loss did not improve
# 26s - loss: 2.8226 - acc: 0.3025 - val_loss: 3.7323 - val_acc: 0.1701
# Epoch 35/100
# Epoch 00034: val_loss did not improve
# 26s - loss: 2.8074 - acc: 0.3045 - val_loss: 3.8843 - val_acc: 0.1713
# Epoch 36/100
# Epoch 00035: val_loss did not improve
# 26s - loss: 2.7928 - acc: 0.3054 - val_loss: 3.7923 - val_acc: 0.1677
# Epoch 37/100
# Epoch 00036: val_loss did not improve
# 26s - loss: 2.7791 - acc: 0.3111 - val_loss: 3.7440 - val_acc: 0.1749
# Epoch 38/100
# Epoch 00037: val_loss improved from 3.64828 to 3.64389, saving model to saved_models/weights.best.MiniVGGModel.hdf5
# 26s - loss: 2.7627 - acc: 0.3060 - val_loss: 3.6439 - val_acc: 0.1892
# Epoch 39/100
# Epoch 00038: val_loss did not improve
# 26s - loss: 2.7458 - acc: 0.3124 - val_loss: 3.7286 - val_acc: 0.1653
# Epoch 40/100
# Epoch 00039: val_loss did not improve
# 26s - loss: 2.7311 - acc: 0.3268 - val_loss: 3.8083 - val_acc: 0.1808
# Epoch 41/100
# Epoch 00040: val_loss did not improve
# 26s - loss: 2.7248 - acc: 0.3231 - val_loss: 3.7505 - val_acc: 0.1760
# Epoch 42/100
# Epoch 00041: val_loss did not improve
# 26s - loss: 2.6955 - acc: 0.3235 - val_loss: 3.7534 - val_acc: 0.1856
# Epoch 43/100
# Epoch 00042: val_loss did not improve
# 26s - loss: 2.6782 - acc: 0.3298 - val_loss: 3.6478 - val_acc: 0.1820
# Epoch 44/100
# Epoch 00043: val_loss did not improve
# 26s - loss: 2.6693 - acc: 0.3328 - val_loss: 3.8002 - val_acc: 0.1892
# Epoch 45/100
# Epoch 00044: val_loss improved from 3.64389 to 3.61082, saving model to saved_models/weights.best.MiniVGGModel.hdf5
# 26s - loss: 2.6515 - acc: 0.3416 - val_loss: 3.6108 - val_acc: 0.1844
# Epoch 46/100
# Epoch 00045: val_loss did not improve
# 26s - loss: 2.6382 - acc: 0.3433 - val_loss: 3.7550 - val_acc: 0.1952
# Epoch 47/100
# Epoch 00046: val_loss did not improve
# 26s - loss: 2.6278 - acc: 0.3421 - val_loss: 3.9278 - val_acc: 0.1749
# Epoch 48/100
# Epoch 00047: val_loss did not improve
# 26s - loss: 2.6232 - acc: 0.3401 - val_loss: 3.9956 - val_acc: 0.1605
# Epoch 49/100
# Epoch 00048: val_loss did not improve
# 26s - loss: 2.5960 - acc: 0.3546 - val_loss: 3.7816 - val_acc: 0.1689
# Epoch 50/100
# Epoch 00049: val_loss did not improve
# 26s - loss: 2.5905 - acc: 0.3528 - val_loss: 3.6760 - val_acc: 0.1796
# Epoch 51/100
# Epoch 00050: val_loss did not improve
# 26s - loss: 2.5879 - acc: 0.3510 - val_loss: 3.7195 - val_acc: 0.1749
# Epoch 52/100
# Epoch 00051: val_loss did not improve
# 26s - loss: 2.5554 - acc: 0.3636 - val_loss: 3.6921 - val_acc: 0.1784
# Epoch 53/100
# Epoch 00052: val_loss did not improve
# 26s - loss: 2.5464 - acc: 0.3566 - val_loss: 3.6758 - val_acc: 0.2000
# Epoch 54/100
# Epoch 00053: val_loss did not improve
# 26s - loss: 2.5281 - acc: 0.3695 - val_loss: 3.8491 - val_acc: 0.1904
# Epoch 55/100
# Epoch 00054: val_loss did not improve
# 26s - loss: 2.5181 - acc: 0.3626 - val_loss: 3.8041 - val_acc: 0.1880
# Epoch 56/100
# Epoch 00055: val_loss did not improve
# 26s - loss: 2.5081 - acc: 0.3693 - val_loss: 3.7176 - val_acc: 0.1976
# Epoch 57/100
# Epoch 00056: val_loss improved from 3.61082 to 3.61047, saving model to saved_models/weights.best.MiniVGGModel.hdf5
# 26s - loss: 2.4860 - acc: 0.3729 - val_loss: 3.6105 - val_acc: 0.1832
# Epoch 58/100
# Epoch 00057: val_loss did not improve
# 26s - loss: 2.4762 - acc: 0.3734 - val_loss: 3.6261 - val_acc: 0.1832
# Epoch 59/100
# Epoch 00058: val_loss did not improve
# 26s - loss: 2.4641 - acc: 0.3828 - val_loss: 3.8616 - val_acc: 0.1737
# Epoch 60/100
# Epoch 00059: val_loss did not improve
# 26s - loss: 2.4542 - acc: 0.3835 - val_loss: 4.5149 - val_acc: 0.1737
# Epoch 61/100
# Epoch 00060: val_loss did not improve
# 26s - loss: 2.4318 - acc: 0.3795 - val_loss: 3.8397 - val_acc: 0.1916
# Epoch 62/100
# Epoch 00061: val_loss did not improve
# 26s - loss: 2.4238 - acc: 0.3925 - val_loss: 3.8405 - val_acc: 0.2024
# Epoch 63/100
# Epoch 00062: val_loss did not improve
# 26s - loss: 2.4156 - acc: 0.3864 - val_loss: 3.7987 - val_acc: 0.1964
# Epoch 64/100
# Epoch 00063: val_loss did not improve
# 26s - loss: 2.4036 - acc: 0.3916 - val_loss: 3.7606 - val_acc: 0.1988
# Epoch 65/100
# Epoch 00064: val_loss did not improve
# 26s - loss: 2.3977 - acc: 0.3904 - val_loss: 3.8633 - val_acc: 0.2168
# Epoch 66/100
# Epoch 00065: val_loss did not improve
# 26s - loss: 2.3829 - acc: 0.3952 - val_loss: 3.8968 - val_acc: 0.1928
# Epoch 67/100
# Epoch 00066: val_loss did not improve
# 26s - loss: 2.3614 - acc: 0.3949 - val_loss: 3.7513 - val_acc: 0.2120
# Epoch 68/100
# Epoch 00067: val_loss did not improve
# 26s - loss: 2.3567 - acc: 0.4049 - val_loss: 3.8912 - val_acc: 0.1916
# Epoch 69/100
# Epoch 00068: val_loss did not improve
# 26s - loss: 2.3443 - acc: 0.4049 - val_loss: 3.6805 - val_acc: 0.1868
# Epoch 70/100
# Epoch 00069: val_loss did not improve
# 26s - loss: 2.3199 - acc: 0.4093 - val_loss: 3.8716 - val_acc: 0.1880
# Epoch 71/100
# Epoch 00070: val_loss did not improve
# 26s - loss: 2.3059 - acc: 0.4136 - val_loss: 3.9640 - val_acc: 0.2072
# Epoch 72/100
# Epoch 00071: val_loss did not improve
# 26s - loss: 2.2987 - acc: 0.4115 - val_loss: 3.8925 - val_acc: 0.1988
# Epoch 73/100
# Epoch 00072: val_loss did not improve
# 26s - loss: 2.2905 - acc: 0.4163 - val_loss: 3.7565 - val_acc: 0.2048
# Epoch 74/100
# Epoch 00073: val_loss improved from 3.61047 to 3.58922, saving model to saved_models/weights.best.MiniVGGModel.hdf5
# 26s - loss: 2.2743 - acc: 0.4181 - val_loss: 3.5892 - val_acc: 0.1880
# Epoch 75/100
# Epoch 00074: val_loss did not improve
# 26s - loss: 2.2608 - acc: 0.4216 - val_loss: 3.8350 - val_acc: 0.1976
# Epoch 76/100
# Epoch 00075: val_loss did not improve
# 26s - loss: 2.2474 - acc: 0.4271 - val_loss: 3.6773 - val_acc: 0.2060
# Epoch 77/100
# Epoch 00076: val_loss did not improve
# 26s - loss: 2.2420 - acc: 0.4228 - val_loss: 3.8107 - val_acc: 0.1844
# Epoch 78/100
# Epoch 00077: val_loss did not improve
# 26s - loss: 2.2257 - acc: 0.4241 - val_loss: 3.7556 - val_acc: 0.2060
# Epoch 79/100
# Epoch 00078: val_loss did not improve
# 26s - loss: 2.2279 - acc: 0.4269 - val_loss: 3.9954 - val_acc: 0.1892
# Epoch 80/100
# Epoch 00079: val_loss did not improve
# 26s - loss: 2.2154 - acc: 0.4299 - val_loss: 3.9377 - val_acc: 0.1593
# Epoch 81/100
# Epoch 00080: val_loss did not improve
# 26s - loss: 2.1964 - acc: 0.4301 - val_loss: 3.7464 - val_acc: 0.2036
# Epoch 82/100
# Epoch 00081: val_loss did not improve
# 26s - loss: 2.1889 - acc: 0.4374 - val_loss: 3.7171 - val_acc: 0.1964
# Epoch 83/100
# Epoch 00082: val_loss did not improve
# 26s - loss: 2.1696 - acc: 0.4452 - val_loss: 3.8122 - val_acc: 0.2012
# Epoch 84/100
# Epoch 00083: val_loss did not improve
# 26s - loss: 2.1605 - acc: 0.4460 - val_loss: 3.9120 - val_acc: 0.1916
# Epoch 85/100
# Epoch 00084: val_loss did not improve
# 26s - loss: 2.1609 - acc: 0.4463 - val_loss: 3.7059 - val_acc: 0.2024
# Epoch 86/100
# Epoch 00085: val_loss did not improve
# 26s - loss: 2.1340 - acc: 0.4478 - val_loss: 4.0409 - val_acc: 0.2012
# Epoch 87/100
# Epoch 00086: val_loss did not improve
# 26s - loss: 2.1245 - acc: 0.4491 - val_loss: 3.9644 - val_acc: 0.1952
# Epoch 88/100
# Epoch 00087: val_loss did not improve
# 26s - loss: 2.1231 - acc: 0.4534 - val_loss: 3.7338 - val_acc: 0.2156
# Epoch 89/100
# Epoch 00088: val_loss did not improve
# 26s - loss: 2.0982 - acc: 0.4566 - val_loss: 4.2588 - val_acc: 0.1904
# Epoch 90/100
# Epoch 00089: val_loss did not improve
# 26s - loss: 2.1073 - acc: 0.4536 - val_loss: 3.7947 - val_acc: 0.1904
# Epoch 91/100
# Epoch 00090: val_loss did not improve
# 26s - loss: 2.0894 - acc: 0.4575 - val_loss: 3.9407 - val_acc: 0.2120
# Epoch 92/100
# Epoch 00091: val_loss did not improve
# 26s - loss: 2.0750 - acc: 0.4599 - val_loss: 3.6919 - val_acc: 0.2096
# Epoch 93/100
# Epoch 00092: val_loss did not improve
# 26s - loss: 2.0545 - acc: 0.4657 - val_loss: 3.9596 - val_acc: 0.1772
# Epoch 94/100
# Epoch 00093: val_loss did not improve
# 26s - loss: 2.0486 - acc: 0.4689 - val_loss: 3.8861 - val_acc: 0.2060
# Epoch 95/100
# Epoch 00094: val_loss did not improve
# 26s - loss: 2.0481 - acc: 0.4696 - val_loss: 3.9231 - val_acc: 0.2168
# Epoch 96/100
# Epoch 00095: val_loss did not improve
# 26s - loss: 2.0446 - acc: 0.4696 - val_loss: 3.8132 - val_acc: 0.2036
# Epoch 97/100
# Epoch 00096: val_loss did not improve
# 26s - loss: 2.0271 - acc: 0.4699 - val_loss: 3.8703 - val_acc: 0.1892
# Epoch 98/100
# Epoch 00097: val_loss did not improve
# 26s - loss: 2.0103 - acc: 0.4757 - val_loss: 3.9453 - val_acc: 0.2168
# Epoch 99/100
# Epoch 00098: val_loss did not improve
# 26s - loss: 2.0101 - acc: 0.4701 - val_loss: 3.8338 - val_acc: 0.2048
# Epoch 100/100
# Epoch 00099: val_loss did not improve
# 26s - loss: 1.9881 - acc: 0.4840 - val_loss: 4.0390 - val_acc: 0.2132

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 100

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.MiniInceptionModel.hdf5', 
                               verbose=1, save_best_only=True)

MiniInceptionHistory100 = MiniInceptionModel.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=2)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/100
# Epoch 00000: val_loss improved from inf to 3.80097, saving model to saved_models/weights.best.MiniInceptionModel.hdf5
# 94s - loss: 2.9629 - acc: 0.2751 - val_loss: 3.8010 - val_acc: 0.1521
# Epoch 2/100
# Epoch 00001: val_loss improved from 3.80097 to 3.76872, saving model to saved_models/weights.best.MiniInceptionModel.hdf5
# 94s - loss: 2.9294 - acc: 0.2922 - val_loss: 3.7687 - val_acc: 0.1916
# Epoch 3/100
# Epoch 00002: val_loss improved from 3.76872 to 3.62785, saving model to saved_models/weights.best.MiniInceptionModel.hdf5
# 94s - loss: 2.8986 - acc: 0.2982 - val_loss: 3.6279 - val_acc: 0.1892
# Epoch 4/100
# Epoch 00003: val_loss did not improve
# 94s - loss: 2.8629 - acc: 0.2943 - val_loss: 3.6791 - val_acc: 0.1784
# Epoch 5/100
# Epoch 00004: val_loss did not improve
# 94s - loss: 2.8501 - acc: 0.3084 - val_loss: 3.6818 - val_acc: 0.1964
# Epoch 6/100
# Epoch 00005: val_loss did not improve
# 94s - loss: 2.8074 - acc: 0.3169 - val_loss: 3.6466 - val_acc: 0.1784
# Epoch 7/100
# Epoch 00006: val_loss improved from 3.62785 to 3.58041, saving model to saved_models/weights.best.MiniInceptionModel.hdf5
# 94s - loss: 2.7884 - acc: 0.3162 - val_loss: 3.5804 - val_acc: 0.1988
# Epoch 8/100
# Epoch 00007: val_loss did not improve
# 94s - loss: 2.7419 - acc: 0.3269 - val_loss: 3.7813 - val_acc: 0.1988
# Epoch 9/100
# Epoch 00008: val_loss did not improve
# 94s - loss: 2.7267 - acc: 0.3251 - val_loss: 3.6388 - val_acc: 0.2024
# Epoch 10/100
# Epoch 00009: val_loss did not improve
# 94s - loss: 2.6971 - acc: 0.3350 - val_loss: 3.7046 - val_acc: 0.2048
# Epoch 11/100
# Epoch 00010: val_loss did not improve
# 94s - loss: 2.6736 - acc: 0.3415 - val_loss: 3.7741 - val_acc: 0.1665
# Epoch 12/100
# Epoch 00011: val_loss did not improve
# 94s - loss: 2.6364 - acc: 0.3466 - val_loss: 3.7208 - val_acc: 0.1940
# Epoch 13/100
# Epoch 00012: val_loss did not improve
# 94s - loss: 2.6201 - acc: 0.3415 - val_loss: 3.6791 - val_acc: 0.2024
# Epoch 14/100
# Epoch 00013: val_loss did not improve
# 94s - loss: 2.5883 - acc: 0.3533 - val_loss: 3.6966 - val_acc: 0.2132
# Epoch 15/100
# Epoch 00014: val_loss did not improve
# 94s - loss: 2.5732 - acc: 0.3582 - val_loss: 3.5967 - val_acc: 0.2120
# Epoch 16/100
# Epoch 00015: val_loss did not improve
# 94s - loss: 2.5239 - acc: 0.3641 - val_loss: 3.8548 - val_acc: 0.1844
# Epoch 17/100
# Epoch 00016: val_loss did not improve
# 94s - loss: 2.5037 - acc: 0.3746 - val_loss: 3.6824 - val_acc: 0.1868
# Epoch 18/100
# Epoch 00017: val_loss improved from 3.58041 to 3.56256, saving model to saved_models/weights.best.MiniInceptionModel.hdf5
# 94s - loss: 2.4840 - acc: 0.3834 - val_loss: 3.5626 - val_acc: 0.2180
# Epoch 19/100
# Epoch 00018: val_loss did not improve
# 94s - loss: 2.4662 - acc: 0.3816 - val_loss: 3.5891 - val_acc: 0.1964
# Epoch 20/100
# Epoch 00019: val_loss did not improve
# 94s - loss: 2.4394 - acc: 0.3873 - val_loss: 3.6728 - val_acc: 0.2263
# Epoch 21/100
# Epoch 00020: val_loss did not improve
# 94s - loss: 2.4165 - acc: 0.3969 - val_loss: 3.6903 - val_acc: 0.1880
# Epoch 22/100
# Epoch 00021: val_loss did not improve
# 94s - loss: 2.3967 - acc: 0.3936 - val_loss: 3.7320 - val_acc: 0.2168
# Epoch 23/100
# Epoch 00022: val_loss did not improve
# 94s - loss: 2.3616 - acc: 0.4031 - val_loss: 3.7672 - val_acc: 0.2240
# Epoch 24/100
# Epoch 00023: val_loss did not improve
# 94s - loss: 2.3325 - acc: 0.4057 - val_loss: 3.9349 - val_acc: 0.2132
# Epoch 25/100
# Epoch 00024: val_loss did not improve
# 94s - loss: 2.3329 - acc: 0.4088 - val_loss: 3.8787 - val_acc: 0.1880
# Epoch 26/100
# Epoch 00025: val_loss did not improve
# 94s - loss: 2.3190 - acc: 0.4084 - val_loss: 3.8111 - val_acc: 0.1940
# Epoch 27/100
# Epoch 00026: val_loss did not improve
# 94s - loss: 2.2817 - acc: 0.4220 - val_loss: 3.7090 - val_acc: 0.1988
# Epoch 28/100
# Epoch 00027: val_loss did not improve
# 94s - loss: 2.2541 - acc: 0.4210 - val_loss: 3.7286 - val_acc: 0.2192
# Epoch 29/100
# Epoch 00028: val_loss did not improve
# 94s - loss: 2.2576 - acc: 0.4205 - val_loss: 3.6698 - val_acc: 0.2251
# Epoch 30/100
# Epoch 00029: val_loss did not improve
# 94s - loss: 2.2417 - acc: 0.4219 - val_loss: 3.8175 - val_acc: 0.2108
# Epoch 31/100
# Epoch 00030: val_loss did not improve
# 94s - loss: 2.2130 - acc: 0.4334 - val_loss: 3.8122 - val_acc: 0.1880
# Epoch 32/100
# Epoch 00031: val_loss did not improve
# 94s - loss: 2.1997 - acc: 0.4401 - val_loss: 3.8133 - val_acc: 0.2132
# Epoch 33/100
# Epoch 00032: val_loss did not improve
# 94s - loss: 2.1832 - acc: 0.4319 - val_loss: 3.8607 - val_acc: 0.1593
# Epoch 34/100
# Epoch 00033: val_loss did not improve
# 94s - loss: 2.1545 - acc: 0.4458 - val_loss: 3.6688 - val_acc: 0.2120
# Epoch 35/100
# Epoch 00034: val_loss did not improve
# 94s - loss: 2.1332 - acc: 0.4543 - val_loss: 3.7048 - val_acc: 0.1952
# Epoch 36/100
# Epoch 00035: val_loss did not improve
# 94s - loss: 2.1272 - acc: 0.4455 - val_loss: 3.6002 - val_acc: 0.2431
# Epoch 37/100
# Epoch 00036: val_loss did not improve
# 94s - loss: 2.1123 - acc: 0.4611 - val_loss: 3.7301 - val_acc: 0.2407
# Epoch 38/100
# Epoch 00037: val_loss did not improve
# 94s - loss: 2.0840 - acc: 0.4630 - val_loss: 3.7131 - val_acc: 0.2395
# Epoch 39/100
# Epoch 00038: val_loss did not improve
# 94s - loss: 2.0770 - acc: 0.4615 - val_loss: 3.7931 - val_acc: 0.2072
# Epoch 40/100
# Epoch 00039: val_loss did not improve
# 94s - loss: 2.0703 - acc: 0.4579 - val_loss: 3.8064 - val_acc: 0.2192
# Epoch 41/100
# Epoch 00040: val_loss did not improve
# 94s - loss: 2.0361 - acc: 0.4711 - val_loss: 4.3397 - val_acc: 0.1916
# Epoch 42/100
# Epoch 00041: val_loss did not improve
# 94s - loss: 2.0306 - acc: 0.4666 - val_loss: 3.7383 - val_acc: 0.2084
# Epoch 43/100
# Epoch 00042: val_loss did not improve
# 94s - loss: 2.0133 - acc: 0.4784 - val_loss: 3.7502 - val_acc: 0.2060
# Epoch 44/100
# Epoch 00043: val_loss did not improve
# 94s - loss: 2.0070 - acc: 0.4734 - val_loss: 3.8027 - val_acc: 0.2216
# Epoch 45/100
# Epoch 00044: val_loss did not improve
# 94s - loss: 1.9686 - acc: 0.4834 - val_loss: 3.7302 - val_acc: 0.2216
# Epoch 46/100
# Epoch 00045: val_loss did not improve
# 94s - loss: 1.9678 - acc: 0.4885 - val_loss: 3.9593 - val_acc: 0.2012
# Epoch 47/100
# Epoch 00046: val_loss did not improve
# 94s - loss: 1.9474 - acc: 0.4891 - val_loss: 3.9208 - val_acc: 0.2383
# Epoch 48/100
# Epoch 00047: val_loss did not improve
# 94s - loss: 1.9249 - acc: 0.4849 - val_loss: 3.8555 - val_acc: 0.2144
# Epoch 49/100
# Epoch 00048: val_loss did not improve
# 94s - loss: 1.9088 - acc: 0.4996 - val_loss: 3.7603 - val_acc: 0.2263
# Epoch 50/100
# Epoch 00049: val_loss did not improve
# 94s - loss: 1.8883 - acc: 0.4981 - val_loss: 3.9862 - val_acc: 0.2263
# Epoch 51/100
# Epoch 00050: val_loss did not improve
# 94s - loss: 1.8941 - acc: 0.4961 - val_loss: 3.7694 - val_acc: 0.2192
# Epoch 52/100
# Epoch 00051: val_loss did not improve
# 94s - loss: 1.8750 - acc: 0.5049 - val_loss: 4.0249 - val_acc: 0.2024
# Epoch 53/100
# Epoch 00052: val_loss did not improve
# 94s - loss: 1.8680 - acc: 0.5049 - val_loss: 3.8372 - val_acc: 0.2240
# Epoch 54/100
# Epoch 00053: val_loss did not improve
# 94s - loss: 1.8506 - acc: 0.5120 - val_loss: 3.8209 - val_acc: 0.2407
# Epoch 55/100
# Epoch 00054: val_loss did not improve
# 94s - loss: 1.8293 - acc: 0.5109 - val_loss: 3.9753 - val_acc: 0.2156
# Epoch 56/100
# Epoch 00055: val_loss did not improve
# 94s - loss: 1.8217 - acc: 0.5177 - val_loss: 3.8445 - val_acc: 0.2287
# Epoch 57/100
# Epoch 00056: val_loss did not improve
# 94s - loss: 1.8062 - acc: 0.5157 - val_loss: 3.7842 - val_acc: 0.2431
# Epoch 58/100
# Epoch 00057: val_loss did not improve
# 94s - loss: 1.8042 - acc: 0.5196 - val_loss: 3.9359 - val_acc: 0.2036
# Epoch 59/100
# Epoch 00058: val_loss did not improve
# 94s - loss: 1.7749 - acc: 0.5238 - val_loss: 3.8942 - val_acc: 0.2287
# Epoch 60/100
# Epoch 00059: val_loss did not improve
# 94s - loss: 1.7796 - acc: 0.5187 - val_loss: 3.9820 - val_acc: 0.2060
# Epoch 61/100
# Epoch 00060: val_loss did not improve
# 94s - loss: 1.7629 - acc: 0.5310 - val_loss: 3.8625 - val_acc: 0.2323
# Epoch 62/100
# Epoch 00061: val_loss did not improve
# 94s - loss: 1.7590 - acc: 0.5271 - val_loss: 4.0438 - val_acc: 0.2407
# Epoch 63/100
# Epoch 00062: val_loss did not improve
# 94s - loss: 1.7360 - acc: 0.5401 - val_loss: 3.9063 - val_acc: 0.2060
# Epoch 64/100
# Epoch 00063: val_loss did not improve
# 94s - loss: 1.7382 - acc: 0.5322 - val_loss: 3.9689 - val_acc: 0.2539
# Epoch 65/100
# Epoch 00064: val_loss did not improve
# 94s - loss: 1.7199 - acc: 0.5391 - val_loss: 4.1871 - val_acc: 0.2431
# Epoch 66/100
# Epoch 00065: val_loss did not improve
# 94s - loss: 1.7084 - acc: 0.5380 - val_loss: 3.9362 - val_acc: 0.2228
# Epoch 67/100
# Epoch 00066: val_loss did not improve
# 94s - loss: 1.6845 - acc: 0.5445 - val_loss: 4.3706 - val_acc: 0.2168
# Epoch 68/100
# Epoch 00067: val_loss did not improve
# 94s - loss: 1.6717 - acc: 0.5482 - val_loss: 4.1889 - val_acc: 0.2419
# Epoch 69/100
# Epoch 00068: val_loss did not improve
# 94s - loss: 1.6687 - acc: 0.5500 - val_loss: 4.0811 - val_acc: 0.2563
# Epoch 70/100
# Epoch 00069: val_loss did not improve
# 94s - loss: 1.6695 - acc: 0.5485 - val_loss: 4.2430 - val_acc: 0.2144
# Epoch 71/100
# Epoch 00070: val_loss did not improve
# 94s - loss: 1.6384 - acc: 0.5530 - val_loss: 3.9991 - val_acc: 0.2251
# Epoch 72/100
# Epoch 00071: val_loss did not improve
# 94s - loss: 1.6213 - acc: 0.5527 - val_loss: 4.0365 - val_acc: 0.2275
# Epoch 73/100
# Epoch 00072: val_loss did not improve
# 94s - loss: 1.6205 - acc: 0.5591 - val_loss: 4.1512 - val_acc: 0.2275
# Epoch 74/100
# Epoch 00073: val_loss did not improve
# 94s - loss: 1.6136 - acc: 0.5585 - val_loss: 4.4357 - val_acc: 0.1976
# Epoch 75/100
# Epoch 00074: val_loss did not improve
# 94s - loss: 1.6032 - acc: 0.5644 - val_loss: 4.2255 - val_acc: 0.1868
# Epoch 76/100
# Epoch 00075: val_loss did not improve
# 94s - loss: 1.5967 - acc: 0.5693 - val_loss: 4.3421 - val_acc: 0.2192
# Epoch 77/100
# Epoch 00076: val_loss did not improve
# 94s - loss: 1.5772 - acc: 0.5650 - val_loss: 4.4302 - val_acc: 0.1521
# Epoch 78/100
# Epoch 00077: val_loss did not improve
# 94s - loss: 1.5764 - acc: 0.5722 - val_loss: 5.0205 - val_acc: 0.2120
# Epoch 79/100
# Epoch 00078: val_loss did not improve
# 94s - loss: 1.5786 - acc: 0.5698 - val_loss: 4.4897 - val_acc: 0.2108
# Epoch 80/100
# Epoch 00079: val_loss did not improve
# 94s - loss: 1.5466 - acc: 0.5775 - val_loss: 4.8502 - val_acc: 0.2299
# Epoch 81/100
# Epoch 00080: val_loss did not improve
# 94s - loss: 1.5565 - acc: 0.5808 - val_loss: 4.9514 - val_acc: 0.1904
# Epoch 82/100
# Epoch 00081: val_loss did not improve
# 94s - loss: 1.5314 - acc: 0.5837 - val_loss: 4.5498 - val_acc: 0.2240
# Epoch 83/100
# Epoch 00082: val_loss did not improve
# 94s - loss: 1.5377 - acc: 0.5795 - val_loss: 4.4854 - val_acc: 0.2407
# Epoch 84/100
# Epoch 00083: val_loss did not improve
# 94s - loss: 1.5345 - acc: 0.5777 - val_loss: 4.1190 - val_acc: 0.2108
# Epoch 85/100
# Epoch 00084: val_loss did not improve
# 94s - loss: 1.5145 - acc: 0.5930 - val_loss: 3.9899 - val_acc: 0.2180
# Epoch 86/100
# Epoch 00085: val_loss did not improve
# 94s - loss: 1.5266 - acc: 0.5834 - val_loss: 4.6939 - val_acc: 0.1868
# Epoch 87/100
# Epoch 00086: val_loss did not improve
# 94s - loss: 1.5125 - acc: 0.5840 - val_loss: 4.4076 - val_acc: 0.2168
# Epoch 88/100
# Epoch 00087: val_loss did not improve
# 94s - loss: 1.4834 - acc: 0.5975 - val_loss: 4.7199 - val_acc: 0.1988
# Epoch 89/100
# Epoch 00088: val_loss did not improve
# 94s - loss: 1.4846 - acc: 0.5904 - val_loss: 4.1550 - val_acc: 0.2168
# Epoch 90/100
# Epoch 00089: val_loss did not improve
# 94s - loss: 1.4828 - acc: 0.5937 - val_loss: 4.8130 - val_acc: 0.2395
# Epoch 91/100
# Epoch 00090: val_loss did not improve
# 94s - loss: 1.4838 - acc: 0.5942 - val_loss: 4.3609 - val_acc: 0.2347
# Epoch 92/100
# Epoch 00091: val_loss did not improve
# 94s - loss: 1.4630 - acc: 0.5933 - val_loss: 5.0598 - val_acc: 0.1844
# Epoch 93/100
# Epoch 00092: val_loss did not improve
# 94s - loss: 1.4649 - acc: 0.5934 - val_loss: 4.5555 - val_acc: 0.2240
# Epoch 94/100
# Epoch 00093: val_loss did not improve
# 94s - loss: 1.4414 - acc: 0.6025 - val_loss: 4.3656 - val_acc: 0.2347
# Epoch 95/100
# Epoch 00094: val_loss did not improve
# 94s - loss: 1.4479 - acc: 0.5987 - val_loss: 4.1849 - val_acc: 0.2335
# Epoch 96/100
# Epoch 00095: val_loss did not improve
# 94s - loss: 1.4133 - acc: 0.6102 - val_loss: 4.3843 - val_acc: 0.2335
# Epoch 97/100
# Epoch 00096: val_loss did not improve
# 94s - loss: 1.4361 - acc: 0.6064 - val_loss: 4.2098 - val_acc: 0.2359
# Epoch 98/100
# Epoch 00097: val_loss did not improve
# 94s - loss: 1.4046 - acc: 0.6112 - val_loss: 4.8085 - val_acc: 0.2120
# Epoch 99/100
# Epoch 00098: val_loss did not improve
# 94s - loss: 1.4119 - acc: 0.6162 - val_loss: 4.1943 - val_acc: 0.2335
# Epoch 100/100
# Epoch 00099: val_loss did not improve
# 94s - loss: 1.3915 - acc: 0.6172 - val_loss: 4.4585 - val_acc: 0.2180

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 100

### Do NOT modify the code below this line.a

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.MiniResNetModel.hdf5', 
                               verbose=1, save_best_only=True)

MiniResNetHitory100 = MiniResNetModel.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=2)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/100
# Epoch 00000: val_loss improved from inf to 3.80753, saving model to saved_models/weights.best.MiniResNetModel.hdf5
# 29s - loss: 3.4502 - acc: 0.1754 - val_loss: 3.8075 - val_acc: 0.1281
# Epoch 2/100
# Epoch 00001: val_loss did not improve
# 29s - loss: 3.4188 - acc: 0.1882 - val_loss: 3.8417 - val_acc: 0.1317
# Epoch 3/100
# Epoch 00002: val_loss improved from 3.80753 to 3.78470, saving model to saved_models/weights.best.MiniResNetModel.hdf5
# 29s - loss: 3.4005 - acc: 0.1895 - val_loss: 3.7847 - val_acc: 0.1509
# Epoch 4/100
# Epoch 00003: val_loss did not improve
# 29s - loss: 3.3838 - acc: 0.1879 - val_loss: 3.8502 - val_acc: 0.1305
# Epoch 5/100
# Epoch 00004: val_loss did not improve
# 29s - loss: 3.3724 - acc: 0.1967 - val_loss: 4.0230 - val_acc: 0.1461
# Epoch 6/100
# Epoch 00005: val_loss improved from 3.78470 to 3.74311, saving model to saved_models/weights.best.MiniResNetModel.hdf5
# 29s - loss: 3.3606 - acc: 0.1960 - val_loss: 3.7431 - val_acc: 0.1617
# Epoch 7/100
# Epoch 00006: val_loss did not improve
# 29s - loss: 3.3285 - acc: 0.2010 - val_loss: 3.7476 - val_acc: 0.1593
# Epoch 8/100
# Epoch 00007: val_loss did not improve
# 29s - loss: 3.3094 - acc: 0.2006 - val_loss: 3.7510 - val_acc: 0.1581
# Epoch 9/100
# Epoch 00008: val_loss did not improve
# 29s - loss: 3.2947 - acc: 0.2046 - val_loss: 4.0266 - val_acc: 0.1293
# Epoch 10/100
# Epoch 00009: val_loss improved from 3.74311 to 3.72509, saving model to saved_models/weights.best.MiniResNetModel.hdf5
# 29s - loss: 3.2849 - acc: 0.2085 - val_loss: 3.7251 - val_acc: 0.1641
# Epoch 11/100
# Epoch 00010: val_loss did not improve
# 29s - loss: 3.2490 - acc: 0.2130 - val_loss: 3.9770 - val_acc: 0.1449
# Epoch 12/100
# Epoch 00011: val_loss did not improve
# 29s - loss: 3.2300 - acc: 0.2216 - val_loss: 3.8574 - val_acc: 0.1389
# Epoch 13/100
# Epoch 00012: val_loss did not improve
# 29s - loss: 3.2369 - acc: 0.2199 - val_loss: 3.8689 - val_acc: 0.1545
# Epoch 14/100
# Epoch 00013: val_loss did not improve
# 29s - loss: 3.2129 - acc: 0.2160 - val_loss: 3.9395 - val_acc: 0.1509
# Epoch 15/100
# Epoch 00014: val_loss did not improve
# 29s - loss: 3.1995 - acc: 0.2222 - val_loss: 3.7358 - val_acc: 0.1353
# Epoch 16/100
# Epoch 00015: val_loss improved from 3.72509 to 3.65409, saving model to saved_models/weights.best.MiniResNetModel.hdf5
# 29s - loss: 3.1801 - acc: 0.2347 - val_loss: 3.6541 - val_acc: 0.1545
# Epoch 17/100
# Epoch 00016: val_loss did not improve
# 29s - loss: 3.1597 - acc: 0.2337 - val_loss: 3.6926 - val_acc: 0.1641
# Epoch 18/100
# Epoch 00017: val_loss did not improve
# 28s - loss: 3.1536 - acc: 0.2281 - val_loss: 3.7974 - val_acc: 0.1581
# Epoch 19/100
# Epoch 00018: val_loss did not improve
# 29s - loss: 3.1400 - acc: 0.2407 - val_loss: 3.7408 - val_acc: 0.1425
# Epoch 20/100
# Epoch 00019: val_loss did not improve
# 29s - loss: 3.1280 - acc: 0.2383 - val_loss: 3.7300 - val_acc: 0.1341
# Epoch 21/100
# Epoch 00020: val_loss did not improve
# 29s - loss: 3.1023 - acc: 0.2437 - val_loss: 3.9444 - val_acc: 0.1126
# Epoch 22/100
# Epoch 00021: val_loss did not improve
# 29s - loss: 3.0867 - acc: 0.2497 - val_loss: 3.7645 - val_acc: 0.1401
# Epoch 23/100
# Epoch 00022: val_loss did not improve
# 29s - loss: 3.0736 - acc: 0.2470 - val_loss: 4.4461 - val_acc: 0.1317
# Epoch 24/100
# Epoch 00023: val_loss did not improve
# 29s - loss: 3.0591 - acc: 0.2500 - val_loss: 3.9825 - val_acc: 0.1569
# Epoch 25/100
# Epoch 00024: val_loss did not improve
# 29s - loss: 3.0432 - acc: 0.2507 - val_loss: 3.8912 - val_acc: 0.1689
# Epoch 26/100
# Epoch 00025: val_loss did not improve
# 29s - loss: 3.0280 - acc: 0.2600 - val_loss: 4.0125 - val_acc: 0.1509
# Epoch 27/100
# Epoch 00026: val_loss did not improve
# 29s - loss: 3.0284 - acc: 0.2563 - val_loss: 3.7473 - val_acc: 0.1784
# Epoch 28/100
# Epoch 00027: val_loss improved from 3.65409 to 3.63896, saving model to saved_models/weights.best.MiniResNetModel.hdf5
# 29s - loss: 2.9878 - acc: 0.2641 - val_loss: 3.6390 - val_acc: 0.1641
# Epoch 29/100
# Epoch 00028: val_loss did not improve
# 29s - loss: 2.9799 - acc: 0.2716 - val_loss: 3.7352 - val_acc: 0.1581
# Epoch 30/100
# Epoch 00029: val_loss improved from 3.63896 to 3.59098, saving model to saved_models/weights.best.MiniResNetModel.hdf5
# 28s - loss: 2.9740 - acc: 0.2723 - val_loss: 3.5910 - val_acc: 0.1737
# Epoch 31/100
# Epoch 00030: val_loss did not improve
# 29s - loss: 2.9607 - acc: 0.2763 - val_loss: 3.8842 - val_acc: 0.1353
# Epoch 32/100
# Epoch 00031: val_loss did not improve
# 29s - loss: 2.9386 - acc: 0.2683 - val_loss: 3.6276 - val_acc: 0.1928
# Epoch 33/100
# Epoch 00032: val_loss did not improve
# 29s - loss: 2.9332 - acc: 0.2746 - val_loss: 3.8840 - val_acc: 0.1689
# Epoch 34/100
# Epoch 00033: val_loss did not improve
# 29s - loss: 2.9078 - acc: 0.2765 - val_loss: 3.7569 - val_acc: 0.1749
# Epoch 35/100
# Epoch 00034: val_loss did not improve
# 29s - loss: 2.8930 - acc: 0.2841 - val_loss: 3.6802 - val_acc: 0.1784
# Epoch 36/100
# Epoch 00035: val_loss did not improve
# 29s - loss: 2.8747 - acc: 0.2763 - val_loss: 3.7160 - val_acc: 0.1808
# Epoch 37/100
# Epoch 00036: val_loss did not improve
# 29s - loss: 2.8746 - acc: 0.2870 - val_loss: 3.8222 - val_acc: 0.1545
# Epoch 38/100
# Epoch 00037: val_loss did not improve
# 29s - loss: 2.8497 - acc: 0.2910 - val_loss: 3.6275 - val_acc: 0.1557
# Epoch 39/100
# Epoch 00038: val_loss did not improve
# 29s - loss: 2.8413 - acc: 0.2948 - val_loss: 3.8607 - val_acc: 0.1928
# Epoch 40/100
# Epoch 00039: val_loss did not improve
# 29s - loss: 2.8369 - acc: 0.2930 - val_loss: 3.8710 - val_acc: 0.1796
# Epoch 41/100
# Epoch 00040: val_loss did not improve
# 29s - loss: 2.8082 - acc: 0.2931 - val_loss: 3.6713 - val_acc: 0.1820
# Epoch 42/100
# Epoch 00041: val_loss did not improve
# 29s - loss: 2.8055 - acc: 0.3021 - val_loss: 3.6531 - val_acc: 0.1713
# Epoch 43/100
# Epoch 00042: val_loss did not improve
# 29s - loss: 2.7948 - acc: 0.3094 - val_loss: 3.8781 - val_acc: 0.1808
# Epoch 44/100
# Epoch 00043: val_loss did not improve
# 29s - loss: 2.7892 - acc: 0.3000 - val_loss: 3.7050 - val_acc: 0.1749
# Epoch 45/100
# Epoch 00044: val_loss did not improve
# 29s - loss: 2.7704 - acc: 0.3039 - val_loss: 3.7925 - val_acc: 0.1820
# Epoch 46/100
# Epoch 00045: val_loss did not improve
# 29s - loss: 2.7447 - acc: 0.3180 - val_loss: 3.6796 - val_acc: 0.1713
# Epoch 47/100
# Epoch 00046: val_loss did not improve
# 29s - loss: 2.7334 - acc: 0.3160 - val_loss: 3.7354 - val_acc: 0.1605
# Epoch 48/100
# Epoch 00047: val_loss did not improve
# 29s - loss: 2.7257 - acc: 0.3115 - val_loss: 3.7041 - val_acc: 0.1760
# Epoch 49/100
# Epoch 00048: val_loss did not improve
# 29s - loss: 2.7140 - acc: 0.3072 - val_loss: 3.6464 - val_acc: 0.1916
# Epoch 50/100
# Epoch 00049: val_loss did not improve
# 29s - loss: 2.6851 - acc: 0.3240 - val_loss: 3.8728 - val_acc: 0.1868
# Epoch 51/100
# Epoch 00050: val_loss did not improve
# 29s - loss: 2.6925 - acc: 0.3190 - val_loss: 3.8059 - val_acc: 0.1832
# Epoch 52/100
# Epoch 00051: val_loss did not improve
# 29s - loss: 2.6760 - acc: 0.3307 - val_loss: 3.7894 - val_acc: 0.1976
# Epoch 53/100
# Epoch 00052: val_loss did not improve
# 29s - loss: 2.6653 - acc: 0.3281 - val_loss: 3.6820 - val_acc: 0.1772
# Epoch 54/100
# Epoch 00053: val_loss did not improve
# 29s - loss: 2.6522 - acc: 0.3314 - val_loss: 3.7519 - val_acc: 0.1856
# Epoch 55/100
# Epoch 00054: val_loss did not improve
# 29s - loss: 2.6404 - acc: 0.3296 - val_loss: 4.1461 - val_acc: 0.1832
# Epoch 56/100
# Epoch 00055: val_loss did not improve
# 29s - loss: 2.6243 - acc: 0.3352 - val_loss: 3.7646 - val_acc: 0.1569
# Epoch 57/100
# Epoch 00056: val_loss did not improve
# 29s - loss: 2.6064 - acc: 0.3406 - val_loss: 3.7393 - val_acc: 0.1832
# Epoch 58/100
# Epoch 00057: val_loss did not improve
# 29s - loss: 2.6039 - acc: 0.3382 - val_loss: 3.6020 - val_acc: 0.2000
# Epoch 59/100
# Epoch 00058: val_loss did not improve
# 29s - loss: 2.5888 - acc: 0.3427 - val_loss: 3.7815 - val_acc: 0.1844
# Epoch 60/100
# Epoch 00059: val_loss did not improve
# 29s - loss: 2.5794 - acc: 0.3418 - val_loss: 3.7331 - val_acc: 0.1928
# Epoch 61/100
# Epoch 00060: val_loss did not improve
# 29s - loss: 2.5591 - acc: 0.3484 - val_loss: 3.9556 - val_acc: 0.1653
# Epoch 62/100
# Epoch 00061: val_loss did not improve
# 29s - loss: 2.5574 - acc: 0.3377 - val_loss: 3.8427 - val_acc: 0.1784
# Epoch 63/100
# Epoch 00062: val_loss did not improve
# 29s - loss: 2.5320 - acc: 0.3527 - val_loss: 3.8668 - val_acc: 0.1449
# Epoch 64/100
# Epoch 00063: val_loss did not improve
# 29s - loss: 2.5214 - acc: 0.3525 - val_loss: 3.8042 - val_acc: 0.1856
# Epoch 65/100
# Epoch 00064: val_loss did not improve
# 29s - loss: 2.5194 - acc: 0.3524 - val_loss: 3.7163 - val_acc: 0.1952
# Epoch 66/100
# Epoch 00065: val_loss did not improve
# 29s - loss: 2.5033 - acc: 0.3504 - val_loss: 3.8440 - val_acc: 0.1916
# Epoch 67/100
# Epoch 00066: val_loss did not improve
# 29s - loss: 2.4908 - acc: 0.3548 - val_loss: 3.6750 - val_acc: 0.2180
# Epoch 68/100
# Epoch 00067: val_loss did not improve
# 29s - loss: 2.4843 - acc: 0.3591 - val_loss: 3.7864 - val_acc: 0.2000
# Epoch 69/100
# Epoch 00068: val_loss did not improve
# 29s - loss: 2.4688 - acc: 0.3615 - val_loss: 3.6162 - val_acc: 0.1856
# Epoch 70/100
# Epoch 00069: val_loss did not improve
# 29s - loss: 2.4498 - acc: 0.3665 - val_loss: 3.6776 - val_acc: 0.1940
# Epoch 71/100
# Epoch 00070: val_loss did not improve
# 29s - loss: 2.4508 - acc: 0.3653 - val_loss: 3.9333 - val_acc: 0.2060
# Epoch 72/100
# Epoch 00071: val_loss did not improve
# 29s - loss: 2.4344 - acc: 0.3683 - val_loss: 4.2428 - val_acc: 0.1928
# Epoch 73/100
# Epoch 00072: val_loss did not improve
# 29s - loss: 2.4225 - acc: 0.3734 - val_loss: 3.7303 - val_acc: 0.1928
# Epoch 74/100
# Epoch 00073: val_loss did not improve
# 29s - loss: 2.4221 - acc: 0.3720 - val_loss: 3.7533 - val_acc: 0.1988
# Epoch 75/100
# Epoch 00074: val_loss did not improve
# 28s - loss: 2.4143 - acc: 0.3787 - val_loss: 3.8276 - val_acc: 0.2096
# Epoch 76/100
# Epoch 00075: val_loss did not improve
# 29s - loss: 2.3947 - acc: 0.3777 - val_loss: 3.7773 - val_acc: 0.2192
# Epoch 77/100
# Epoch 00076: val_loss did not improve
# 29s - loss: 2.3730 - acc: 0.3841 - val_loss: 3.8176 - val_acc: 0.2036
# Epoch 78/100
# Epoch 00077: val_loss did not improve
# 29s - loss: 2.3596 - acc: 0.3885 - val_loss: 3.8148 - val_acc: 0.1521
# Epoch 79/100
# Epoch 00078: val_loss did not improve
# 29s - loss: 2.3613 - acc: 0.3873 - val_loss: 3.7322 - val_acc: 0.2132
# Epoch 80/100
# Epoch 00079: val_loss did not improve
# 29s - loss: 2.3479 - acc: 0.3913 - val_loss: 3.9335 - val_acc: 0.2216
# Epoch 81/100
# Epoch 00080: val_loss did not improve
# 28s - loss: 2.3385 - acc: 0.3976 - val_loss: 3.7156 - val_acc: 0.2120
# Epoch 82/100
# Epoch 00081: val_loss did not improve
# 29s - loss: 2.3276 - acc: 0.4031 - val_loss: 3.9571 - val_acc: 0.2012
# Epoch 83/100
# Epoch 00082: val_loss did not improve
# 29s - loss: 2.3026 - acc: 0.3961 - val_loss: 3.8057 - val_acc: 0.1713
# Epoch 84/100
# Epoch 00083: val_loss did not improve
# 29s - loss: 2.2975 - acc: 0.4073 - val_loss: 3.8402 - val_acc: 0.2012
# Epoch 85/100
# Epoch 00084: val_loss did not improve
# 29s - loss: 2.2882 - acc: 0.4003 - val_loss: 3.9608 - val_acc: 0.2012
# Epoch 86/100
# Epoch 00085: val_loss did not improve
# 29s - loss: 2.2892 - acc: 0.3984 - val_loss: 4.1468 - val_acc: 0.2132
# Epoch 87/100
# Epoch 00086: val_loss did not improve
# 29s - loss: 2.2740 - acc: 0.4031 - val_loss: 3.7792 - val_acc: 0.1940
# Epoch 88/100
# Epoch 00087: val_loss did not improve
# 29s - loss: 2.2614 - acc: 0.4067 - val_loss: 4.3292 - val_acc: 0.2000
# Epoch 89/100
# Epoch 00088: val_loss did not improve
# 29s - loss: 2.2327 - acc: 0.4136 - val_loss: 4.3300 - val_acc: 0.2120
# Epoch 90/100
# Epoch 00089: val_loss did not improve
# 29s - loss: 2.2470 - acc: 0.4142 - val_loss: 3.8572 - val_acc: 0.2287
# Epoch 91/100
# Epoch 00090: val_loss did not improve
# 29s - loss: 2.2311 - acc: 0.4171 - val_loss: 3.7566 - val_acc: 0.1725
# Epoch 92/100
# Epoch 00091: val_loss did not improve
# 29s - loss: 2.2173 - acc: 0.4202 - val_loss: 3.9123 - val_acc: 0.1940
# Epoch 93/100
# Epoch 00092: val_loss did not improve
# 29s - loss: 2.2049 - acc: 0.4193 - val_loss: 3.7855 - val_acc: 0.1976
# Epoch 94/100
# Epoch 00093: val_loss did not improve
# 29s - loss: 2.1960 - acc: 0.4219 - val_loss: 3.9566 - val_acc: 0.1940
# Epoch 95/100
# Epoch 00094: val_loss did not improve
# 29s - loss: 2.1728 - acc: 0.4231 - val_loss: 3.9497 - val_acc: 0.1964
# Epoch 96/100
# Epoch 00095: val_loss did not improve
# 28s - loss: 2.1764 - acc: 0.4280 - val_loss: 3.8963 - val_acc: 0.2216
# Epoch 97/100
# Epoch 00096: val_loss did not improve
# 28s - loss: 2.1671 - acc: 0.4283 - val_loss: 4.0101 - val_acc: 0.1928
# Epoch 98/100
# Epoch 00097: val_loss did not improve
# 28s - loss: 2.1571 - acc: 0.4347 - val_loss: 3.9234 - val_acc: 0.2335
# Epoch 99/100
# Epoch 00098: val_loss did not improve
# 29s - loss: 2.1377 - acc: 0.4353 - val_loss: 3.8708 - val_acc: 0.1665
# Epoch 100/100
# Epoch 00099: val_loss did not improve
# 29s - loss: 2.1432 - acc: 0.4422 - val_loss: 4.0161 - val_acc: 0.2132

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
BenchmarkModel.load_weights('saved_models/weights.best.BenchmarkModel.hdf5')

# %%
MiniVGGModel.load_weights('saved_models/weights.best.MiniVGGModel.hdf5')

# %%
MiniInceptionModel.load_weights('saved_models/weights.best.MiniInceptionModel.hdf5')

# %%
MiniResNetModel.load_weights('saved_models/weights.best.MiniResNetModel.hdf5')

# %%
import matplotlib.pyplot as plt

# summarize history for accuracy
plt.plot(MiniVGGHistory100.history['acc'], linestyle=':', color='black')
plt.plot(MiniVGGHistory100.history['val_acc'], linestyle='-', color='black')
plt.plot(MiniInceptionHistory100.history['acc'], linestyle=':', color='blue')
plt.plot(MiniInceptionHistory100.history['val_acc'], linestyle='-', color='blue')
plt.plot(MiniResNetHitory100.history['acc'], linestyle=':', color='yellow')
plt.plot(MiniResNetHitory100.history['val_acc'], linestyle='-', color='yellow')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['VGG_trn', 'VGG_tst', 'Incept_trn', 'Incept_tst', 'Res_trn', 
           'Res_tst'], loc='upper left')
plt.show()
# summarize history for loss
plt.plot(MiniVGGHistory100.history['loss'], linestyle=':', color='black')
plt.plot(MiniVGGHistory100.history['val_loss'], linestyle='-', color='black')
plt.plot(MiniInceptionHistory100.history['loss'], linestyle=':', color='blue')
plt.plot(MiniInceptionHistory100.history['val_loss'], linestyle='-', color='blue')
plt.plot(MiniResNetHitory100.history['loss'], linestyle=':', color='yellow')
plt.plot(MiniResNetHitory100.history['val_loss'], linestyle='-', color='yellow')
plt.title('model loss')
plt.ylabel('loss')
plt.xlabel('epoch')
plt.legend(['VGG_trn', 'VGG_tst', 'Incept_trn', 'Incept_tst', 'Res_trn', 
           'Res_tst'], loc='upper left')
plt.show()

# %% [markdown]
# ### Test the Model
#
# Try out your model on the test dataset of dog images.  Ensure that your test accuracy is greater than 1%.

# %%
# get index of predicted dog breed for each image in test set
pred_BenchmarkModel = [np.argmax(BenchmarkModel.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(pred_BenchmarkModel)==np.argmax(test_targets, axis=1))/len(pred_BenchmarkModel)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 12.4402%

# %%
# get index of predicted dog breed for each image in test set
pred_MiniVGGModel = [np.argmax(MiniVGGModel.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(pred_MiniVGGModel)==np.argmax(test_targets, axis=1))/len(pred_MiniVGGModel)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 19.4976%

# %%
# get index of predicted dog breed for each image in test set
pred_MiniInceptionModel = [np.argmax(MiniInceptionModel.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(pred_MiniInceptionModel)==np.argmax(test_targets, axis=1))/len(pred_MiniInceptionModel)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 21.5311%

# %%
# get index of predicted dog breed for each image in test set
pred_MiniResNetModel = [np.argmax(MiniResNetModel.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(pred_MiniResNetModel)==np.argmax(test_targets, axis=1))/len(pred_MiniResNetModel)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 16.5072%

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Use a CNN to Classify Dog Breeds
#
# To reduce training time without sacrificing accuracy, we show you how to train a CNN using transfer learning.  In the following step, you will get a chance to use transfer learning to train your own CNN.
#
# ### Obtain Bottleneck Features

# %%
# bottleneck_features = np.load('bottleneck_features/DogVGG16Data.npz')
# 3train_VGG16 = bottleneck_features['train']
# valid_VGG16 = bottleneck_features['valid']
# test_VGG16 = bottleneck_features['test']

# %% [markdown]
# ### Model Architecture
#
# The model uses the the pre-trained VGG-16 model as a fixed feature extractor, where the last convolutional output of VGG-16 is fed as input to our model.  We only add a global average pooling layer and a fully connected layer, where the latter contains one node for each dog category and is equipped with a softmax.

# %%
VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:]))
VGG16_model.add(Dense(133, activation='softmax'))

VGG16_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_2 ( (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229.0
# Trainable params: 68,229.0
# Non-trainable params: 0.0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### Train the Model

# %%
# checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG16.hdf5', 
#                                verbose=1, save_best_only=True)

# VGG16_model.fit(train_VGG16, train_targets, 
#           validation_data=(valid_VGG16, valid_targets),
#           epochs=20, batch_size=20, callbacks=[checkpointer], verbose=2)

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
VGG16_model.load_weights('saved_models/weights.best.VGG16.hdf5')

# %% [markdown]
# ### Test the Model
#
# Now, we can use the CNN to test how well it identifies breed within our test dataset of dog images.  We print the test accuracy below.

# %%
# get index of predicted dog breed for each image in test set
VGG16_predictions = [np.argmax(VGG16_model.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 42.1053%

# %% [markdown]
# ### Predict Dog Breed with the Model

# %%
from extract_bottleneck_features import *

def VGG16_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# In Step 4, we used transfer learning to create a CNN using VGG-16 bottleneck features.  In this section, you must use the bottleneck features from a different pre-trained model.  To make things easier for you, we have pre-computed the features for all of the networks that are currently available in Keras:
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# The files are encoded as such:
#
#     Dog{network}Data.npz
#
# where `{network}`, in the above filename, can be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.  Pick one of the above architectures, download the corresponding bottleneck features, and store the downloaded file in the `bottleneck_features/` folder in the repository.
#
# ### (IMPLEMENTATION) Obtain Bottleneck Features
#
# In the code block below, extract the bottleneck features corresponding to the train, test, and validation sets by running the following:
#
#     bottleneck_features = np.load('bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         <your model's name>.summary()
#
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.
#
# __Answer:__ I tried two bottleneck features here, one is the ResNet50, the other is the Xception network. On top of the bottleneck features, I add a GlobalAveragePooling layer and a fully conneted layer before finally reach the softmax output layer. Because this structure is adopted by both ResNet and Xeption network. Although in Xception network the final fully connected layer is optional, there results show that this layer do increase the accuracy, so I keep it here.

# %%
### TODO: Obtain bottleneck features from another pre-trained CNN.

# Obtain bottleneck features from Resnet50
bottleneck_features = np.load('bottleneck_features/DogResnet50Data.npz')
train_Resnet50 = bottleneck_features['train']
valid_Resnet50 = bottleneck_features['valid']
test_Resnet50 = bottleneck_features['test']

# model architecture of dog breed prediction model with Resnet50 bottleneck featuress
Resnet50_model = Sequential()
Resnet50_model.add(GlobalAveragePooling2D(input_shape=train_Resnet50.shape[1:]))
Resnet50_model.add(Dense(133, activation='softmax'))
Resnet50_model.summary()

# compile Resnet50
Resnet50_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# train the model
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.Resnet50.hdf5', 
                               verbose=1, save_best_only=True)
Resnet50Hisory40 = Resnet50_model.fit(train_Resnet50, train_targets, 
          validation_data=(valid_Resnet50, valid_targets),
          epochs=40, batch_size=20, callbacks=[checkpointer], verbose=2)

# load the model with the best validation loss
Resnet50_model.load_weights('saved_models/weights.best.Resnet50.hdf5')

# get index of predicted dog breed for each image in test set
Resnet50_predictions = [np.argmax(Resnet50_model.predict(np.expand_dims(feature, axis=0))) for feature in test_Resnet50]

# report test accuracy
test_accuracy = 100*np.sum(np.array(Resnet50_predictions)==np.argmax(test_targets, axis=1))/len(Resnet50_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_9 ( (None, 2048)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 133)               272517
# =================================================================
# Total params: 272,517.0
# Trainable params: 272,517.0
# Non-trainable params: 0.0
# _________________________________________________________________
# Train on 6680 samples, validate on 835 samples
# Epoch 1/40
# Epoch 00000: val_loss improved from inf to 0.80884, saving model to saved_models/weights.best.Resnet50.hdf5
# 2s - loss: 1.6503 - acc: 0.5934 - val_loss: 0.8088 - val_acc: 0.7509
# Epoch 2/40
# Epoch 00001: val_loss improved from 0.80884 to 0.67219, saving model to saved_models/weights.best.Resnet50.hdf5
# 1s - loss: 0.4366 - acc: 0.8618 - val_loss: 0.6722 - val_acc: 0.7952
# Epoch 3/40
# Epoch 00002: val_loss improved from 0.67219 to 0.67185, saving model to saved_models/weights.best.Resnet50.hdf5
# 1s - loss: 0.2637 - acc: 0.9127 - val_loss: 0.6719 - val_acc: 0.7928
# Epoch 4/40
# Epoch 00003: val_loss did not improve
# 1s - loss: 0.1716 - acc: 0.9467 - val_loss: 0.7491 - val_acc: 0.7892
# Epoch 5/40
# Epoch 00004: val_loss did not improve
# 1s - loss: 0.1220 - acc: 0.9638 - val_loss: 0.6927 - val_acc: 0.8263
# Epoch 6/40
# Epoch 00005: val_loss improved from 0.67185 to 0.66394, saving model to saved_models/weights.best.Resnet50.hdf5
# 2s - loss: 0.0880 - acc: 0.9725 - val_loss: 0.6639 - val_acc: 0.8180
# Epoch 7/40
# Epoch 00006: val_loss did not improve
# 1s - loss: 0.0643 - acc: 0.9814 - val_loss: 0.6734 - val_acc: 0.8144
# Epoch 8/40
# Epoch 00007: val_loss did not improve
# 1s - loss: 0.0471 - acc: 0.9855 - val_loss: 0.7440 - val_acc: 0.8263
# Epoch 9/40
# Epoch 00008: val_loss did not improve
# 1s - loss: 0.0373 - acc: 0.9895 - val_loss: 0.7686 - val_acc: 0.8120
# Epoch 10/40
# Epoch 00009: val_loss did not improve
# 1s - loss: 0.0287 - acc: 0.9916 - val_loss: 0.7822 - val_acc: 0.8156
# Epoch 11/40
# Epoch 00010: val_loss did not improve
# 1s - loss: 0.0217 - acc: 0.9937 - val_loss: 0.7665 - val_acc: 0.8347
# Epoch 12/40
# Epoch 00011: val_loss did not improve
# 1s - loss: 0.0195 - acc: 0.9955 - val_loss: 0.7627 - val_acc: 0.8204
# Epoch 13/40
# Epoch 00012: val_loss did not improve
# 1s - loss: 0.0136 - acc: 0.9970 - val_loss: 0.7619 - val_acc: 0.8180
# Epoch 14/40
# Epoch 00013: val_loss did not improve
# 1s - loss: 0.0115 - acc: 0.9973 - val_loss: 0.8519 - val_acc: 0.8240
# Epoch 15/40
# Epoch 00014: val_loss did not improve
# 1s - loss: 0.0095 - acc: 0.9979 - val_loss: 0.8525 - val_acc: 0.8204
# Epoch 16/40
# Epoch 00015: val_loss did not improve
# 1s - loss: 0.0095 - acc: 0.9978 - val_loss: 0.8110 - val_acc: 0.8419
# Epoch 17/40
# Epoch 00016: val_loss did not improve
# 1s - loss: 0.0077 - acc: 0.9975 - val_loss: 0.8296 - val_acc: 0.8359
# Epoch 18/40
# Epoch 00017: val_loss did not improve
# 1s - loss: 0.0080 - acc: 0.9985 - val_loss: 0.9055 - val_acc: 0.8251
# Epoch 19/40
# Epoch 00018: val_loss did not improve
# 1s - loss: 0.0078 - acc: 0.9984 - val_loss: 0.9224 - val_acc: 0.8299
# Epoch 20/40
# Epoch 00019: val_loss did not improve
# 1s - loss: 0.0077 - acc: 0.9982 - val_loss: 0.8745 - val_acc: 0.8359
# Epoch 21/40
# Epoch 00020: val_loss did not improve
# 1s - loss: 0.0042 - acc: 0.9991 - val_loss: 1.0039 - val_acc: 0.8228
# Epoch 22/40
# Epoch 00021: val_loss did not improve
# 1s - loss: 0.0047 - acc: 0.9985 - val_loss: 0.9554 - val_acc: 0.8263
# Epoch 23/40
# Epoch 00022: val_loss did not improve
# 1s - loss: 0.0050 - acc: 0.9987 - val_loss: 0.9892 - val_acc: 0.8275
# Epoch 24/40
# Epoch 00023: val_loss did not improve
# 1s - loss: 0.0054 - acc: 0.9988 - val_loss: 0.9787 - val_acc: 0.8251
# Epoch 25/40
# Epoch 00024: val_loss did not improve
# 1s - loss: 0.0048 - acc: 0.9991 - val_loss: 1.0403 - val_acc: 0.8299
# Epoch 26/40
# Epoch 00025: val_loss did not improve
# 1s - loss: 0.0048 - acc: 0.9988 - val_loss: 1.0079 - val_acc: 0.8359
# Epoch 27/40
# Epoch 00026: val_loss did not improve
# 1s - loss: 0.0044 - acc: 0.9988 - val_loss: 1.0244 - val_acc: 0.8299
# Epoch 28/40
# Epoch 00027: val_loss did not improve
# 1s - loss: 0.0054 - acc: 0.9990 - val_loss: 1.0961 - val_acc: 0.8275
# Epoch 29/40
# Epoch 00028: val_loss did not improve
# 1s - loss: 0.0056 - acc: 0.9985 - val_loss: 1.0958 - val_acc: 0.8204
# Epoch 30/40
# Epoch 00029: val_loss did not improve
# 1s - loss: 0.0046 - acc: 0.9988 - val_loss: 1.0909 - val_acc: 0.8275
# Epoch 31/40
# Epoch 00030: val_loss did not improve
# 1s - loss: 0.0042 - acc: 0.9990 - val_loss: 1.0854 - val_acc: 0.8275
# Epoch 32/40
# Epoch 00031: val_loss did not improve
# 1s - loss: 0.0058 - acc: 0.9985 - val_loss: 1.0641 - val_acc: 0.8287
# Epoch 33/40
# Epoch 00032: val_loss did not improve
# 1s - loss: 0.0055 - acc: 0.9988 - val_loss: 1.1146 - val_acc: 0.8323
# Epoch 34/40
# Epoch 00033: val_loss did not improve
# 1s - loss: 0.0043 - acc: 0.9987 - val_loss: 1.1262 - val_acc: 0.8263
# Epoch 35/40
# Epoch 00034: val_loss did not improve
# 1s - loss: 0.0044 - acc: 0.9988 - val_loss: 1.1396 - val_acc: 0.8263
# Epoch 36/40
# Epoch 00035: val_loss did not improve
# 1s - loss: 0.0033 - acc: 0.9990 - val_loss: 1.1595 - val_acc: 0.8323
# Epoch 37/40
# Epoch 00036: val_loss did not improve
# 2s - loss: 0.0043 - acc: 0.9988 - val_loss: 1.1182 - val_acc: 0.8311
# Epoch 38/40
# Epoch 00037: val_loss did not improve
# 2s - loss: 0.0045 - acc: 0.9985 - val_loss: 1.1440 - val_acc: 0.8311
# Epoch 39/40
# Epoch 00038: val_loss did not improve
# 2s - loss: 0.0035 - acc: 0.9984 - val_loss: 1.1623 - val_acc: 0.8251
# Epoch 40/40
# Epoch 00039: val_loss did not improve
# 2s - loss: 0.0041 - acc: 0.9987 - val_loss: 1.1694 - val_acc: 0.8228
# Test accuracy: 80.5024%

# %%
# Obtain bottleneck features from Xception
bottleneck_features = np.load('bottleneck_features/DogXceptionData.npz')
train_Xception = bottleneck_features['train']
valid_Xception = bottleneck_features['valid']
test_Xception = bottleneck_features['test']

# model architecture of dog breed prediction model with Xception bottleneck featuress
Xception_model = Sequential()
Xception_model.add(GlobalAveragePooling2D(input_shape=train_Xception.shape[1:]))
Xception_model.add(Dense(133, activation='softmax'))
Xception_model.summary()

# compile Xception
Xception_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# train the model
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.Xception.hdf5', 
                               verbose=1, save_best_only=True)
XceptionHisory40 = Xception_model.fit(train_Xception, train_targets, 
          validation_data=(valid_Xception, valid_targets),
          epochs=40, batch_size=20, callbacks=[checkpointer], verbose=2)

# load the model with the best validation loss
Xception_model.load_weights('saved_models/weights.best.Xception.hdf5')

# get index of predicted dog breed for each image in test set
Xception_predictions = [np.argmax(Xception_model.predict(np.expand_dims(feature, axis=0))) for feature in test_Xception]

# report test accuracy
test_accuracy = 100*np.sum(np.array(Xception_predictions)==np.argmax(test_targets, axis=1))/len(Xception_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_10  (None, 2048)              0
# _________________________________________________________________
# dense_10 (Dense)             (None, 133)               272517
# =================================================================
# Total params: 272,517.0
# Trainable params: 272,517.0
# Non-trainable params: 0.0
# _________________________________________________________________
# Train on 6680 samples, validate on 835 samples
# Epoch 1/40
# Epoch 00000: val_loss improved from inf to 0.54991, saving model to saved_models/weights.best.Xception.hdf5
# 4s - loss: 1.0553 - acc: 0.7382 - val_loss: 0.5499 - val_acc: 0.8156
# Epoch 2/40
# Epoch 00001: val_loss improved from 0.54991 to 0.48076, saving model to saved_models/weights.best.Xception.hdf5
# 4s - loss: 0.4049 - acc: 0.8714 - val_loss: 0.4808 - val_acc: 0.8539
# Epoch 3/40
# Epoch 00002: val_loss improved from 0.48076 to 0.47137, saving model to saved_models/weights.best.Xception.hdf5
# 4s - loss: 0.3265 - acc: 0.8978 - val_loss: 0.4714 - val_acc: 0.8563
# Epoch 4/40
# Epoch 00003: val_loss improved from 0.47137 to 0.47016, saving model to saved_models/weights.best.Xception.hdf5
# 4s - loss: 0.2765 - acc: 0.9123 - val_loss: 0.4702 - val_acc: 0.8635
# Epoch 5/40
# Epoch 00004: val_loss did not improve
# 4s - loss: 0.2410 - acc: 0.9235 - val_loss: 0.5085 - val_acc: 0.8587
# Epoch 6/40
# Epoch 00005: val_loss did not improve
# 4s - loss: 0.2177 - acc: 0.9331 - val_loss: 0.5191 - val_acc: 0.8539
# Epoch 7/40
# Epoch 00006: val_loss did not improve
# 4s - loss: 0.1964 - acc: 0.9383 - val_loss: 0.5315 - val_acc: 0.8479
# Epoch 8/40
# Epoch 00007: val_loss did not improve
# 4s - loss: 0.1749 - acc: 0.9448 - val_loss: 0.5612 - val_acc: 0.8563
# Epoch 9/40
# Epoch 00008: val_loss did not improve
# 4s - loss: 0.1589 - acc: 0.9518 - val_loss: 0.5701 - val_acc: 0.8599
# Epoch 10/40
# Epoch 00009: val_loss did not improve
# 4s - loss: 0.1483 - acc: 0.9567 - val_loss: 0.5469 - val_acc: 0.8611
# Epoch 11/40
# Epoch 00010: val_loss did not improve
# 4s - loss: 0.1353 - acc: 0.9581 - val_loss: 0.5699 - val_acc: 0.8611
# Epoch 12/40
# Epoch 00011: val_loss did not improve
# 4s - loss: 0.1293 - acc: 0.9606 - val_loss: 0.5589 - val_acc: 0.8623
# Epoch 13/40
# Epoch 00012: val_loss did not improve
# 4s - loss: 0.1189 - acc: 0.9656 - val_loss: 0.6074 - val_acc: 0.8671
# Epoch 14/40
# Epoch 00013: val_loss did not improve
# 4s - loss: 0.1054 - acc: 0.9680 - val_loss: 0.6483 - val_acc: 0.8539
# Epoch 15/40
# Epoch 00014: val_loss did not improve
# 4s - loss: 0.1018 - acc: 0.9690 - val_loss: 0.6332 - val_acc: 0.8563
# Epoch 16/40
# Epoch 00015: val_loss did not improve
# 4s - loss: 0.0983 - acc: 0.9735 - val_loss: 0.6274 - val_acc: 0.8575
# Epoch 17/40
# Epoch 00016: val_loss did not improve
# 4s - loss: 0.0913 - acc: 0.9741 - val_loss: 0.6349 - val_acc: 0.8563
# Epoch 18/40
# Epoch 00017: val_loss did not improve
# 4s - loss: 0.0839 - acc: 0.9759 - val_loss: 0.6677 - val_acc: 0.8575
# Epoch 19/40
# Epoch 00018: val_loss did not improve
# 4s - loss: 0.0834 - acc: 0.9760 - val_loss: 0.6530 - val_acc: 0.8551
# Epoch 20/40
# Epoch 00019: val_loss did not improve
# 4s - loss: 0.0762 - acc: 0.9787 - val_loss: 0.6742 - val_acc: 0.8563
# Epoch 21/40
# Epoch 00020: val_loss did not improve
# 4s - loss: 0.0694 - acc: 0.9802 - val_loss: 0.6958 - val_acc: 0.8527
# Epoch 22/40
# Epoch 00021: val_loss did not improve
# 4s - loss: 0.0648 - acc: 0.9810 - val_loss: 0.7450 - val_acc: 0.8527
# Epoch 23/40
# Epoch 00022: val_loss did not improve
# 4s - loss: 0.0611 - acc: 0.9826 - val_loss: 0.7015 - val_acc: 0.8611
# Epoch 24/40
# Epoch 00023: val_loss did not improve
# 4s - loss: 0.0572 - acc: 0.9841 - val_loss: 0.7444 - val_acc: 0.8491
# Epoch 25/40
# Epoch 00024: val_loss did not improve
# 4s - loss: 0.0578 - acc: 0.9837 - val_loss: 0.7564 - val_acc: 0.8551
# Epoch 26/40
# Epoch 00025: val_loss did not improve
# 4s - loss: 0.0548 - acc: 0.9843 - val_loss: 0.7377 - val_acc: 0.8587
# Epoch 27/40
# Epoch 00026: val_loss did not improve
# 4s - loss: 0.0506 - acc: 0.9862 - val_loss: 0.7682 - val_acc: 0.8563
# Epoch 28/40
# Epoch 00027: val_loss did not improve
# 4s - loss: 0.0490 - acc: 0.9862 - val_loss: 0.7664 - val_acc: 0.8443
# Epoch 29/40
# Epoch 00028: val_loss did not improve
# 4s - loss: 0.0433 - acc: 0.9886 - val_loss: 0.7888 - val_acc: 0.8599
# Epoch 30/40
# Epoch 00029: val_loss did not improve
# 4s - loss: 0.0451 - acc: 0.9877 - val_loss: 0.7726 - val_acc: 0.8551
# Epoch 31/40
# Epoch 00030: val_loss did not improve
# 4s - loss: 0.0413 - acc: 0.9891 - val_loss: 0.8044 - val_acc: 0.8599
# Epoch 32/40
# Epoch 00031: val_loss did not improve
# 4s - loss: 0.0419 - acc: 0.9891 - val_loss: 0.7948 - val_acc: 0.8647
# Epoch 33/40
# Epoch 00032: val_loss did not improve
# 4s - loss: 0.0401 - acc: 0.9894 - val_loss: 0.8292 - val_acc: 0.8551
# Epoch 34/40
# Epoch 00033: val_loss did not improve
# 4s - loss: 0.0359 - acc: 0.9901 - val_loss: 0.8556 - val_acc: 0.8527
# Epoch 35/40
# Epoch 00034: val_loss did not improve
# 4s - loss: 0.0361 - acc: 0.9906 - val_loss: 0.8270 - val_acc: 0.8551
# Epoch 36/40
# Epoch 00035: val_loss did not improve
# 4s - loss: 0.0349 - acc: 0.9909 - val_loss: 0.8339 - val_acc: 0.8611
# Epoch 37/40
# Epoch 00036: val_loss did not improve
# 4s - loss: 0.0330 - acc: 0.9913 - val_loss: 0.8602 - val_acc: 0.8551
# Epoch 38/40
# Epoch 00037: val_loss did not improve
# 4s - loss: 0.0318 - acc: 0.9906 - val_loss: 0.8774 - val_acc: 0.8563
# Epoch 39/40
# Epoch 00038: val_loss did not improve
# 4s - loss: 0.0303 - acc: 0.9928 - val_loss: 0.8481 - val_acc: 0.8599
# Epoch 40/40
# Epoch 00039: val_loss did not improve
# 4s - loss: 0.0302 - acc: 0.9919 - val_loss: 0.9030 - val_acc: 0.8515
# Test accuracy: 85.2871%

# %%
plt.plot(Resnet50Hisory40.history['acc'], linestyle = '-', color = 'black')
plt.plot(Resnet50Hisory40.history['val_acc'], linestyle = ':', color = 'black')
plt.plot(XceptionHisory40.history['acc'], linestyle = '-', color = 'green')
plt.plot(XceptionHisory40.history['val_acc'], linestyle = '-', color = 'green')
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.show()
plt.plot(Resnet50Hisory40.history['loss'], linestyle = '-', color = 'black')
plt.plot(Resnet50Hisory40.history['val_loss'], linestyle = ':', color = 'black')
plt.plot(XceptionHisory40.history['loss'], linestyle = '-', color = 'green')
plt.plot(XceptionHisory40.history['val_loss'], linestyle = ':', color = 'green')
plt.show()

# %% [markdown]
# ### (IMPLEMENTATION) Compile the Model

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %% [markdown]
# ### (IMPLEMENTATION) Load the Model with the Best Validation Loss

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Ensure that your test accuracy is greater than 60%.

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan_hound`, etc) that is predicted by your model.
#
# Similar to the analogous function in Step 5, your function should have three steps:
# 1. Extract the bottleneck features corresponding to the chosen CNN model.
# 2. Supply the bottleneck features as input to the model to return the predicted vector.  Note that the argmax of this prediction vector gives the index of the predicted dog breed.
# 3. Use the `dog_names` array defined in Step 0 of this notebook to return the corresponding breed.
#
# The functions to extract the bottleneck features can be found in `extract_bottleneck_features.py`, and they have been imported in an earlier code cell.  To obtain the bottleneck features corresponding to your chosen CNN architecture, you need to use the function
#
#     extract_{network}
#
# where `{network}`, in the above filename, should be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.

# %%
# Obtain bottleneck features from DenseNet
train_DenseNet = np.load('bottleneck_features/DogDenseNet_train.npy')
valid_DenseNet = np.load('bottleneck_features/DogDenseNet_valid.npy')
test_DenseNet = np.load('bottleneck_features/DogDenseNet_test.npy')

# model architecture of dog breed prediction model with DenseNet bottleneck featuress
DenseNet_try = Sequential()
DenseNet_try.add(Dense(133, activation='softmax', input_shape=train_DenseNet.shape[1:]))
DenseNet_try.summary()

# compile 
DenseNet_try.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# train 
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.DenseNet.hdf5', 
                               verbose=1, save_best_only=True)
DenseNetHisory40 = DenseNet_try.fit(train_DenseNet, train_targets, 
          validation_data=(valid_DenseNet, valid_targets),
          epochs=40, batch_size=20, callbacks=[checkpointer], verbose=2)

# load the model with the best validation loss
DenseNet_try.load_weights('saved_models/weights.best.DenseNet.hdf5')

# get index of predicted dog breed for each image in test set
DenseNet_predictions = [np.argmax(DenseNet_try.predict(np.expand_dims(feature, axis=0))) for feature in test_DenseNet]

# report test accuracy
test_accuracy = 100*np.sum(np.array(DenseNet_predictions)==np.argmax(test_targets, axis=1))/len(DenseNet_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_3 (Dense)              (None, 133)               293797
# =================================================================
# Total params: 293,797.0
# Trainable params: 293,797
# Non-trainable params: 0.0
# _________________________________________________________________
# Train on 6680 samples, validate on 835 samples
# Epoch 1/40
# Epoch 00000: val_loss improved from inf to 0.67851, saving model to saved_models/weights.best.DenseNet.hdf5
# 1s - loss: 1.6932 - acc: 0.6260 - val_loss: 0.6785 - val_acc: 0.7952
# Epoch 2/40
# Epoch 00001: val_loss improved from 0.67851 to 0.45518, saving model to saved_models/weights.best.DenseNet.hdf5
# 1s - loss: 0.3942 - acc: 0.8871 - val_loss: 0.4552 - val_acc: 0.8539
# Epoch 3/40
# Epoch 00002: val_loss improved from 0.45518 to 0.41346, saving model to saved_models/weights.best.DenseNet.hdf5
# 1s - loss: 0.2369 - acc: 0.9305 - val_loss: 0.4135 - val_acc: 0.8623
# Epoch 4/40
# Epoch 00003: val_loss improved from 0.41346 to 0.38184, saving model to saved_models/weights.best.DenseNet.hdf5
# 2s - loss: 0.1723 - acc: 0.9497 - val_loss: 0.3818 - val_acc: 0.8743
# Epoch 5/40
# Epoch 00004: val_loss improved from 0.38184 to 0.35845, saving model to saved_models/weights.best.DenseNet.hdf5
# 1s - loss: 0.1292 - acc: 0.9623 - val_loss: 0.3585 - val_acc: 0.8886
# Epoch 6/40
# Epoch 00005: val_loss did not improve
# 2s - loss: 0.1031 - acc: 0.9708 - val_loss: 0.3654 - val_acc: 0.8695
# Epoch 7/40
# Epoch 00006: val_loss did not improve
# 2s - loss: 0.0766 - acc: 0.9786 - val_loss: 0.3912 - val_acc: 0.8683
# Epoch 8/40
# Epoch 00007: val_loss did not improve
# 1s - loss: 0.0639 - acc: 0.9832 - val_loss: 0.3680 - val_acc: 0.8862
# Epoch 9/40
# Epoch 00008: val_loss did not improve
# 1s - loss: 0.0513 - acc: 0.9861 - val_loss: 0.4035 - val_acc: 0.8623
# Epoch 10/40
# Epoch 00009: val_loss did not improve
# 1s - loss: 0.0416 - acc: 0.9906 - val_loss: 0.3787 - val_acc: 0.8743
# Epoch 11/40
# Epoch 00010: val_loss did not improve
# 1s - loss: 0.0358 - acc: 0.9886 - val_loss: 0.3833 - val_acc: 0.8754
# Epoch 12/40
# Epoch 00011: val_loss did not improve
# 1s - loss: 0.0309 - acc: 0.9916 - val_loss: 0.3922 - val_acc: 0.8731
# Epoch 13/40
# Epoch 00012: val_loss did not improve
# 1s - loss: 0.0243 - acc: 0.9946 - val_loss: 0.3860 - val_acc: 0.8910
# Epoch 14/40
# Epoch 00013: val_loss did not improve
# 2s - loss: 0.0212 - acc: 0.9937 - val_loss: 0.3832 - val_acc: 0.8814
# Epoch 15/40
# Epoch 00014: val_loss did not improve
# 2s - loss: 0.0174 - acc: 0.9946 - val_loss: 0.3813 - val_acc: 0.8910
# Epoch 16/40
# Epoch 00015: val_loss did not improve
# 1s - loss: 0.0161 - acc: 0.9952 - val_loss: 0.3730 - val_acc: 0.8958
# Epoch 17/40
# Epoch 00016: val_loss did not improve
# 1s - loss: 0.0127 - acc: 0.9970 - val_loss: 0.4027 - val_acc: 0.8778
# Epoch 18/40
# Epoch 00017: val_loss did not improve
# 1s - loss: 0.0112 - acc: 0.9969 - val_loss: 0.4188 - val_acc: 0.8766
# Epoch 19/40
# Epoch 00018: val_loss did not improve
# 2s - loss: 0.0097 - acc: 0.9970 - val_loss: 0.4035 - val_acc: 0.8838
# Epoch 20/40
# Epoch 00019: val_loss did not improve
# 1s - loss: 0.0090 - acc: 0.9973 - val_loss: 0.4314 - val_acc: 0.8838
# Epoch 21/40
# Epoch 00020: val_loss did not improve
# 1s - loss: 0.0081 - acc: 0.9975 - val_loss: 0.4184 - val_acc: 0.8754
# Epoch 22/40
# Epoch 00021: val_loss did not improve
# 1s - loss: 0.0069 - acc: 0.9978 - val_loss: 0.4430 - val_acc: 0.8814
# Epoch 23/40
# Epoch 00022: val_loss did not improve
# 1s - loss: 0.0064 - acc: 0.9978 - val_loss: 0.4155 - val_acc: 0.8838
# Epoch 24/40
# Epoch 00023: val_loss did not improve
# 2s - loss: 0.0060 - acc: 0.9979 - val_loss: 0.4619 - val_acc: 0.8802
# Epoch 25/40
# Epoch 00024: val_loss did not improve
# 2s - loss: 0.0053 - acc: 0.9981 - val_loss: 0.4447 - val_acc: 0.8850
# Epoch 26/40
# Epoch 00025: val_loss did not improve
# 2s - loss: 0.0052 - acc: 0.9985 - val_loss: 0.4305 - val_acc: 0.8874
# Epoch 27/40
# Epoch 00026: val_loss did not improve
# 2s - loss: 0.0049 - acc: 0.9984 - val_loss: 0.4629 - val_acc: 0.8862
# Epoch 28/40
# Epoch 00027: val_loss did not improve
# 1s - loss: 0.0052 - acc: 0.9988 - val_loss: 0.4602 - val_acc: 0.8850
# Epoch 29/40
# Epoch 00028: val_loss did not improve
# 1s - loss: 0.0041 - acc: 0.9982 - val_loss: 0.4576 - val_acc: 0.8778
# Epoch 30/40
# Epoch 00029: val_loss did not improve
# 1s - loss: 0.0039 - acc: 0.9988 - val_loss: 0.4591 - val_acc: 0.8874
# Epoch 31/40
# Epoch 00030: val_loss did not improve
# 1s - loss: 0.0047 - acc: 0.9988 - val_loss: 0.4704 - val_acc: 0.8898
# Epoch 32/40
# Epoch 00031: val_loss did not improve
# 1s - loss: 0.0039 - acc: 0.9987 - val_loss: 0.4867 - val_acc: 0.8826
# Epoch 33/40
# Epoch 00032: val_loss did not improve
# 1s - loss: 0.0037 - acc: 0.9988 - val_loss: 0.4862 - val_acc: 0.8886
# Epoch 34/40
# Epoch 00033: val_loss did not improve
# 1s - loss: 0.0029 - acc: 0.9988 - val_loss: 0.4709 - val_acc: 0.8898
# Epoch 35/40
# Epoch 00034: val_loss did not improve
# 1s - loss: 0.0029 - acc: 0.9990 - val_loss: 0.5057 - val_acc: 0.8719
# Epoch 36/40
# Epoch 00035: val_loss did not improve
# 1s - loss: 0.0026 - acc: 0.9994 - val_loss: 0.5059 - val_acc: 0.8850
# Epoch 37/40
# Epoch 00036: val_loss did not improve
# 1s - loss: 0.0030 - acc: 0.9988 - val_loss: 0.5361 - val_acc: 0.8874
# Epoch 38/40
# Epoch 00037: val_loss did not improve
# 1s - loss: 0.0025 - acc: 0.9993 - val_loss: 0.5433 - val_acc: 0.8850
# Epoch 39/40
# Epoch 00038: val_loss did not improve
# 1s - loss: 0.0026 - acc: 0.9993 - val_loss: 0.4984 - val_acc: 0.8862
# Epoch 40/40
# Epoch 00039: val_loss did not improve
# 1s - loss: 0.0026 - acc: 0.9990 - val_loss: 0.5370 - val_acc: 0.8778
# Test accuracy: 86.7225%

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 5 to predict dog breed.
#
# Some sample output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_output.png)
#
#
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.

# %% [markdown]
# ---
# <a id='step7'></a>
# ## Step 7: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that __you__ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.
#
# __Answer:__

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.
